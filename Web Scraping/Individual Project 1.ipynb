# %%
from bs4 import BeautifulSoup
import requests
import time

# %% [markdown]
# ## Part 1: Scraping and Saving HTML Content

# %%
# 1. Identify the target
url = 'https://sfbay.craigslist.org/search/zip?sort=date#search=1~gallery~0~0'

# %% [markdown]
# 2. Interact with the Page-Sorting
#  - When changing the sorting from newest to oldest, a segment of "?sort=dateoldest" showed up in the URL.
#  - Sorting change can also be triggered by changing the segment to "?sort=date" directly in the URL.
#  - A GET request is made when changing the sort order, as we are requesting data from the web server.
#  - In this case, the variable in the URL associated with sorting is "sort".

# %% [markdown]
# 3. Interact with the Page-Pagination
#  - The way to move betweeen pages from the URL is to change the number at this segment: "gallery~0".
#  - In this case, the variable in the URL associated with page changes is "gallery". Changing the variable value can change the page and position of the page you see.

# %%
# 4. Fetch Listing URLs
headers = {'User-agent': 'Mozilla/5.0'}
page = requests.get(url, headers = headers)
soup = BeautifulSoup(page.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="craigslist" property="og:site_name"/>
#   <meta content="preview" name="twitter:card"/>
#   <meta content="SF bay area free stuff - craigslist" property="og:title"/>
#   <meta content="SF bay area free stuff - craigslist" name="description"/>
#   <meta content="SF bay area free stuff - craigslist" property="og:description"/>
#   <meta content="https://sfbay.craigslist.org/search/zip" property="og:url"/>
#   <title>
#    SF bay area free stuff - craigslist
#   </title>
#   <link href="https://sfbay.craigslist.org/search/zip" rel="canonical"/>
#   <link href="https://sfbay.craigslist.org/search/zip" hreflang="x-default" rel="alternate"/>
#   <link href="/favicon.ico" id="favicon" rel="icon"/>
#   <script id="ld_searchpage_data" type="application/ld+json">
#    {"description":"Free Stuff in SF Bay Area","@context":"https://schema.org","@type":"SearchResultsPage","breadcrumb":{"itemListElement":[{"position":1,"name":"sfbay.craigslist.org","item":"https://sfbay.craigslist.org","@type":"ListItem"},{"@type":"ListItem","item":"https://sfbay.craigslist.org/search/sss","name":"for sale","position":2},{"name":"free stuff","item":"https://sfbay.craigslist.org/search/zip","@type":"ListItem","position":3}],"@context":"https://schema.org","@type":"BreadcrumbList"}}
#   </script>
#   <script id="ld_searchpage_results" type="application/ld+json">
#    {"itemListElement":[],"@context":"https://schema.org","@type":"ItemList"}
#   </script>
#   <style>
#    body {
#             font-family: sans-serif;
#         }
#
#         #no-js {
#             position: fixed;
#             z-index: 100000;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             overflow:auto;
#             margin: 0;
#             background: transparent;
#         }
#
#         #no-js h1 {
#             margin: 0;
#             padding: .5em;
#             color: #00E;
#             background-color: #cccccc;
#         }
#
#         #no-js  p {
#             margin: 1em;
#         }
#
#         .no-js header,
#         .no-js form,
#         .no-js .tsb,
#         .unsupported-browser header,
#         .unsupported-browser form,
#         .unsupported-browser .tsb {
#             display: none;
#         }
#
#         #curtain {
#             display: none;
#             position: fixed;
#             z-index: 9000;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#             background: transparent;
#         }
#
#         .show-curtain #curtain {
#             display: block;
#         }
#
#         #curtain .cover,
#         #curtain .content {
#             position: absolute;
#             display: block;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#         }
#
#         #curtain .cover {
#             z-index: 1;
#             background-color: white;
#         }
#
#         .show-curtain #curtain .cover {
#             opacity: 0.7;
#         }
#
#         .show-curtain.clear #curtain .cover {
#             opacity: 0;
#         }
#
#         .show-curtain.opaque #curtain .cover {
#             opacity: 1;
#         }
#
#         #curtain .content {
#             z-index: 2;
#             background: transparent;
#             color: #00E;
#
#             display: flex;
#             flex-direction: column;
#             justify-content: center;
#             align-items: center;
#         }
#
#         .unrecoverable #curtain .content,
#         .unsupported-browser #curtain .content {
#             display: block;
#             align-items: start;
#         }
#
#         #curtain h1 {
#             margin: 0;
#             padding: .5em;
#             background-color: #cccccc;
#         }
#
#         #curtain  p {
#             margin: 1em;
#             color: black;
#         }
#
#         .pacify #curtain .icom-:after {
#             content: "\eb23";
#         }
#
#         #curtain .text {
#             display: none;
#         }
#
#         .loading #curtain .text.loading,
#         .reading #curtain .text.reading,
#         .writing #curtain .text.writing,
#         .saving #curtain .text.saving,
#         .searching #curtain .text.searching,
#         .unrecoverable #curtain .text.unrecoverable,
#         .message #curtain .text.message {
#             display: block;
#         }
#
#         .unrecoverable #curtain .text.unrecoverable {
#         }
#
#         @keyframes rotate {
#             from {
#                 transform: rotate(0deg);
#             }
#             to {
#                 transform: rotate(359deg);
#             }
#         }
#
#         .pacify #curtain .icom- {
#             font-size: 3em;
#             animation: rotate 2s infinite linear;
#         }
#   </style>
#   <style>
#    body {
#             margin: 0;
#             border: 0;
#             padding: 0;
#         }
#
#         ol.cl-static-search-results, .cl-static-header {
#             display:none;
#         }
#
#         .no-js ol.cl-static-search-results, .no-js .cl-static-header {
#             display:block;
#         }
#   </style>
#  </head>
#  <body class="no-js search">
#   <div class="cl-content">
#    <main>
#    </main>
#   </div>
#   <div id="curtain">
#    <div class="cover">
#    </div>
#    <div class="content">
#     <div class="icom-">
#     </div>
#     <div class="text loading">
#      loading
#     </div>
#     <div class="text reading">
#      reading
#     </div>
#     <div class="text writing">
#      writing
#     </div>
#     <div class="text saving">
#      saving
#     </div>
#     <div class="text searching">
#      searching
#     </div>
#     <div class="text message" id="curtainText">
#     </div>
#     <div class="text unrecoverable">
#      <p>
#       <a href="#" id="cl-unrecoverable-hard-refresh" onclick="location.reload(true);">
#        refresh the page.
#       </a>
#      </p>
#     </div>
#    </div>
#   </div>
#   <script>
#    (function() {
#             try {
#                 window.onpageshow = function(event) {
#                     if (event.persisted && cl.upTime()>1000 && /iPhone/.test(navigator.userAgent)) {
#                         window.location.reload();
#                     }
#                 };
#
#                 window.addEventListener('DOMContentLoaded', function() {
#                     document.body.classList.remove('no-js');
#                 });
#                 document.body.classList.remove('no-js');
#             } catch(e) {
#                 console.log(e);
#             }
#         })();
#   </script>
#   <script crossorigin="anonymous" src="https://www.craigslist.org/static/www/baa6cf7b7135bef8e3098858037bf9d742326367.js">
#   </script>
#   <script>
#    window.cl.init(
#              'https://www.craigslist.org/static/www/',
#              '',
#              'www',
#              'search',
#              {
# 'areaAbbrev': "sfo",
# 'areaCoords': ["37.500000","-122.250000"],
# 'areaId': "1",
# 'areaName': "SF bay area",
# 'defaultLocale': "en_US",
# 'initialCategoryAbbr': "zip",
# 'location': {"areaId":1,"lon":-122.268,"lat":37.495,"city":"San Carlos","postal":"94070","country":"US","radius":3,"region":"CA","url":"sfbay.craigslist.org"},
# 'nearbyAreas': [{"host":"stockton","name":"stockton"},{"name":"monterey","host":"monterey"},{"name":"modesto","host":"modesto"},{"name":"sacramento","host":"sacramento"},{"name":"merced","host":"merced"},{"host":"goldcountry","name":"gold country"},{"name":"yuba-sutter","host":"yubasutter"},{"host":"mendocino","name":"mendocino co"},{"name":"fresno","host":"fresno"},{"name":"chico","host":"chico"},{"name":"hanford","host":"hanford"},{"name":"san luis obispo","host":"slo"},{"host":"visalia","name":"visalia-tulare"},{"name":"reno","host":"reno"},{"host":"santamaria","name":"santa maria"},{"host":"redding","name":"redding"},{"host":"susanville","name":"susanville"},{"name":"bakersfield","host":"bakersfield"}],
# 'seoLinks': 0,
# 'subareas': [{"abbr":"sfc","id":1,"name":"san francisco"},{"abbr":"sby","id":2,"name":"south bay"},{"abbr":"eby","name":"east bay","id":3},{"abbr":"pen","id":4,"name":"peninsula"},{"name":"north bay","id":5,"abbr":"nby"},{"name":"santa cruz","id":6,"abbr":"scz"}],
# 'whereAmI': {"subareaId":0,"area":{"name":"SF bay area","abbr":"sfo","lat":"37.500000","lon":"-122.250000","subareas":[{"lat":"37.816622","lon":"-122.097694","name":"east bay","abbr":"eby","id":3,"description":"east bay area"},{"id":5,"description":"north bay / marin","lon":"-122.552650","lat":"38.213112","name":"north bay","abbr":"nby"},{"lat":"37.513420","lon":"-122.237935","name":"peninsula","abbr":"pen","id":4,"description":"peninsula"},{"lat":"37.774419","lon":"-122.413431","abbr":"sfc","name":"san francisco","description":"city of san francisco","id":1},{"name":"santa cruz","abbr":"scz","lon":"-121.961466","lat":"36.981202","id":6,"description":"santa cruz co"},{"lon":"-121.925176","lat":"37.331272","abbr":"sby","name":"south bay","description":"south bay area","id":2}],"id":1,"description":"SF bay area","country":"US","hostname":"sfbay","region":"CA"},"nearbyAreas":[{"subareas":[],"lat":"39.728600","lon":"-121.835999","abbr":"chc","name":"chico","hostname":"chico","region":"CA","country":"US","description":"chico, CA","id":187},{"abbr":"fre","name":"fresno","subareas":[],"lon":"-119.771004","lat":"36.747799","country":"US","description":"fresno / madera","id":43,"region":"CA","hostname":"fresno"},{"region":"CA","hostname":"goldcountry","country":"US","description":"gold country","id":373,"subareas":[],"lon":"-120.801003","lat":"38.732498","abbr":"gld","name":"gold country"},{"region":"CA","hostname":"hanford","id":709,"country":"US","description":"hanford-corcoran","lat":"36.327400","lon":"-119.646004","subareas":[],"name":"hanford","abbr":"hnf"},{"description":"mendocino county","country":"US","id":454,"region":"CA","hostname":"mendocino","abbr":"mdo","name":"mendocino co","subareas":[],"lon":"-123.430000","lat":"39.363098"},{"description":"merced, CA","country":"US","id":285,"hostname":"merced","region":"CA","abbr":"mer","name":"merced","subareas":[],"lat":"37.302200","lon":"-120.482002"},{"lat":"37.639198","lon":"-120.996002","subareas":[],"name":"modesto","abbr":"mod","region":"CA","hostname":"modesto","id":96,"description":"modesto, CA","country":"US"},{"hostname":"monterey","region":"CA","country":"US","description":"monterey bay","id":102,"subareas":[],"lon":"-121.893997","lat":"36.600300","abbr":"mtb","name":"monterey"},{"subareas":[],"lat":"40.586700","lon":"-122.390999","abbr":"rdd","name":"redding","region":"CA","hostname":"redding","country":"US","description":"redding, CA","id":188},{"abbr":"rno","name":"reno","subareas":[],"lat":"39.529701","lon":"-119.813004","description":"reno / tahoe","country":"US","id":92,"region":"NV","hostname":"reno"},{"lat":"38.581699","lon":"-121.492996","subareas":[],"name":"sacramento","abbr":"sac","hostname":"sacramento","region":"CA","id":12,"country":"US","description":"sacramento"},{"subareas":[],"lat":"35.282799","lon":"-120.658997","abbr":"slo","name":"san luis obispo","hostname":"slo","region":"CA","description":"san luis obispo","country":"US","id":191},{"name":"santa maria","abbr":"smx","lon":"-120.433296","lat":"34.963799","subareas":[],"id":710,"country":"US","description":"santa maria, CA","hostname":"santamaria","region":"CA"},{"hostname":"stockton","region":"CA","description":"stockton, CA","country":"US","id":97,"subareas":[],"lat":"37.957802","lon":"-121.290001","abbr":"stk","name":"stockton"},{"abbr":"ssn","name":"susanville","subareas":[],"lat":"40.416302","lon":"-120.653000","country":"US","description":"susanville, CA","id":707,"hostname":"susanville","region":"CA"},{"abbr":"vis","name":"visalia-tulare","subareas":[],"lon":"-119.291000","lat":"36.330299","description":"visalia-tulare","country":"US","id":346,"region":"CA","hostname":"visalia"},{"description":"yuba-sutter, CA","country":"US","id":456,"region":"CA","hostname":"yubasutter","abbr":"ybs","name":"yuba-sutter","subareas":[],"lat":"39.144402","lon":"-121.647003"}],"searchLocation":0}
# },
#              0
#          );
#   </script>
#   <iframe id="cl-local-storage" src="https://www.craigslist.org/static/www/localStorage-092e9f9e2f09450529e744902aa7cdb3a5cc868d.html" style="display:none;">
#   </iframe>
#   <script>
#    window.cl.specialCurtainMessages = {
#             unsupportedBrowser: [
#                 "We've detected you are using a browser that is missing critical features.",
#                 "Please visit craigslist from a modern browser."
#             ],
#             unrecoverableError: [
#                 "There was an error loading the page."
#             ]
#         };
#   </script>
#   <div class="cl-static-header">
#    <a href="/">
#     craigslist
#    </a>
#    <h1>
#     Free Stuff in SF Bay Area
#    </h1>
#   </div>
#   <ol class="cl-static-search-results">
#    <li class="cl-static-hub-links">
#     <div>
#      see also
#     </div>
#    </li>
#    <li class="cl-static-search-result" title="Bolster pillow">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/el-cerrito-bolster-pillow/7714551361.html">
#      <div class="title">
#       Bolster pillow
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        albany / el cerrito
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Ankle Foot Medical CAM Boots Unisex SMALL">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/ankle-foot-medical-cam-boots-unisex/7714551359.html">
#      <div class="title">
#       Ankle Foot Medical CAM Boots Unisex SMALL
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        oakland lake merritt / grand
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Nice Sleeper sofa">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/santa-rosa-nice-sleeper-sofa/7710871185.html">
#      <div class="title">
#       Nice Sleeper sofa
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        petaluma
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Unopened Baby Diaper Ointment">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-unopened-baby-diaper-ointment/7713234275.html">
#      <div class="title">
#       Unopened Baby Diaper Ointment
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        berkeley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="ClearLax (MiraLax generic )">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-clearlax-miralax-generic/7713208049.html">
#      <div class="title">
#       ClearLax (MiraLax generic )
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        berkeley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Two drawer file cabinet">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/sunnyvale-two-drawer-file-cabinet/7714549739.html">
#      <div class="title">
#       Two drawer file cabinet
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        sunnyvale
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="FREE Outdoor Tiles">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-free-outdoor-tiles/7714549146.html">
#      <div class="title">
#       FREE Outdoor Tiles
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san jose south
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Nightstand">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/sunnyvale-nightstand/7714549199.html">
#      <div class="title">
#       Nightstand
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        sunnyvale
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free futon mattress 72”x52” (mattress only)">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/san-lorenzo-free-futon-mattress-72x52/7706646621.html">
#      <div class="title">
#       Free futon mattress 72”x52” (mattress only)
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Lorenzo
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Four Kitchen Chairs">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/novato-four-kitchen-chairs/7713913055.html">
#      <div class="title">
#       Four Kitchen Chairs
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        novato
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free and great condition- Cal King box springs">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/fremont-free-and-great-condition-cal/7714546351.html">
#      <div class="title">
#       Free and great condition- Cal King box springs
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Union City
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Garage cabinets (2)">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/belmont-garage-cabinets/7714546515.html">
#      <div class="title">
#       Garage cabinets (2)
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        belmont
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="FREE 10 Waterproof ID Badge Holders in Hard Plastic with Lanyard">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-free-10-waterproof-id-badge/7714546254.html">
#      <div class="title">
#       FREE 10 Waterproof ID Badge Holders in Hard Plastic with Lanyard
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san jose east
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Wooden glider rocking chair with pads (free)">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-wooden-glider-rocking/7714546001.html">
#      <div class="title">
#       Wooden glider rocking chair with pads (free)
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free garden wall cinderblocks">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/el-cerrito-free-garden-wall-cinderblocks/7714545180.html">
#      <div class="title">
#       Free garden wall cinderblocks
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        albany / el cerrito
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free cabinet organizers">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/el-cerrito-free-cabinet-organizers/7714545164.html">
#      <div class="title">
#       Free cabinet organizers
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        albany / el cerrito
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free wood floors">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/el-cerrito-free-wood-floors/7714545155.html">
#      <div class="title">
#       Free wood floors
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        albany / el cerrito
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title='Dell SE2216H 22" LCD Monitor'>
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-dell-se2216h-22-lcd-monitor/7714544897.html">
#      <div class="title">
#       Dell SE2216H 22" LCD Monitor
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        oakland downtown
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="IKEA book shelf">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/corte-madera-ikea-book-shelf/7714544660.html">
#      <div class="title">
#       IKEA book shelf
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        corte madera
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Moving Boxes - Small, Medium and Large">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-moving-boxes-small-medium/7714543953.html">
#      <div class="title">
#       Moving Boxes - Small, Medium and Large
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        nob hill
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Metal Storage Shed - FREE, Must Remove">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/palo-alto-metal-storage-shed-free-must/7714542844.html">
#      <div class="title">
#       Metal Storage Shed - FREE, Must Remove
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        palo alto
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free area rugs">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-free-area-rugs/7714542941.html">
#      <div class="title">
#       Free area rugs
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san jose west
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="baby or pet gate">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/south-san-francisco-baby-or-pet-gate/7714542814.html">
#      <div class="title">
#       baby or pet gate
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        south san francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Gravel and sand">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-free-gravel-and-sand/7713184817.html">
#      <div class="title">
#       Free Gravel and sand
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san jose east
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Used artificial grass and Sand (only sand, grass is gone)">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-used-artificial-grass-and-sand/7708883310.html">
#      <div class="title">
#       Used artificial grass and Sand (only sand, grass is gone)
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san jose east
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Specialized Road Bike Shoes size 46, USED">
#     <a href="https://sfbay.craigslist.org/scz/zip/d/santa-cruz-specialized-road-bike-shoes/7707034031.html">
#      <div class="title">
#       Specialized Road Bike Shoes size 46, USED
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        scotts valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Bathtub Door (missing screws)">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-bathtub-door-missing/7714540403.html">
#      <div class="title">
#       Bathtub Door (missing screws)
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        potrero hill
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free - entertainment center">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/martinez-free-entertainment-center/7713076849.html">
#      <div class="title">
#       Free - entertainment center
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        concord / pleasant hill / martinez
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Car Seat">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/south-san-francisco-car-seat/7714538428.html">
#      <div class="title">
#       Car Seat
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        South San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Antique Floor Standing Radio and Walker">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/antioch-free-antique-floor-standing/7714536489.html">
#      <div class="title">
#       Free Antique Floor Standing Radio and Walker
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        pittsburg / antioch
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Twin size bed frame">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-twin-size-bed-frame/7714536307.html">
#      <div class="title">
#       Twin size bed frame
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="IKEA Laptop Stand/Bed Tray">
#     <a href="https://sfbay.craigslist.org/scz/zip/d/freedom-ikea-laptop-stand-bed-tray/7714535545.html">
#      <div class="title">
#       IKEA Laptop Stand/Bed Tray
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        watsonville
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Built-in Counter-depth Kitchenaid KSSC36QTS Architect Series II">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/san-ramon-built-in-counter-depth/7714535179.html">
#      <div class="title">
#       Built-in Counter-depth Kitchenaid KSSC36QTS Architect Series II
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        danville / san ramon
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Non working chest freezer">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/milpitas-non-working-chest-freezer/7712074474.html">
#      <div class="title">
#       Non working chest freezer
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Milpitas
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Box of breastmilk storage bags">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-box-of-breastmilk-storage-bags/7714534032.html">
#      <div class="title">
#       Box of breastmilk storage bags
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        oakland lake merritt / grand
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Computer Monitor">
#     <a href="https://sfbay.craigslist.org/scz/zip/d/freedom-free-computer-monitor/7714533705.html">
#      <div class="title">
#       Free Computer Monitor
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        watsonville
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Kid Science Kit - FREE!">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-kid-science-kit-free/7714532990.html">
#      <div class="title">
#       Kid Science Kit - FREE!
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        oakland lake merritt / grand
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free pregnancy pillow">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-free-pregnancy-pillow/7707497306.html">
#      <div class="title">
#       Free pregnancy pillow
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        albany / el cerrito
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="FREE Istanbul Metro Card">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-free-istanbul-metro-card/7706359982.html">
#      <div class="title">
#       FREE Istanbul Metro Card
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        oakland lake merritt / grand
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Stuff">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-free-stuff/7711572302.html">
#      <div class="title">
#       Free Stuff
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        oakland lake merritt / grand
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free lamps.">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/pleasant-hill-free-lamps/7714530780.html">
#      <div class="title">
#       Free lamps.
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Pleasant Hill
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Book ends">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/hayward-book-ends/7714529989.html">
#      <div class="title">
#       Book ends
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Hayward
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="HP Color LaserJet CP1518ni">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/san-mateo-hp-color-laserjet-cp1518ni/7714529428.html">
#      <div class="title">
#       HP Color LaserJet CP1518ni
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san mateo
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Chair">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/fremont-chair/7714529410.html">
#      <div class="title">
#       Chair
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        fremont / union city / newark
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free beautiful antique twin bed frame">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/castro-valley-free-beautiful-antique/7706573192.html">
#      <div class="title">
#       Free beautiful antique twin bed frame
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Castro Valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="3 sinks * Free delivery Monday 2/5 10 am Berkeley, Oakland, Emeryville">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-sinks-free-delivery-monday-am/7714528699.html">
#      <div class="title">
#       3 sinks * Free delivery Monday 2/5 10 am Berkeley, Oakland, Emeryville
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Oakland
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Walgreens Ultrasonic Humidifier for Free">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-walgreens-ultrasonic/7714526026.html">
#      <div class="title">
#       Walgreens Ultrasonic Humidifier for Free
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        saratoga
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Bag of crayons">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/palo-alto-bag-of-crayons/7713466445.html">
#      <div class="title">
#       Bag of crayons
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        palo alto
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Lots of good boxes for free">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-lots-of-good-boxes-for/7714524888.html">
#      <div class="title">
#       Lots of good boxes for free
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        noe valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Rug">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/brentwood-rug/7714523278.html">
#      <div class="title">
#       Rug
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        brentwood / oakley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="FREE American Standard Toilet">
#     <a href="https://sfbay.craigslist.org/scz/zip/d/mount-hermon-free-american-standard/7711920009.html">
#      <div class="title">
#       FREE American Standard Toilet
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        scotts valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="“Child Guard” Plastic Bag and Canister for Medications">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-child-guard-plastic-bag/7712999768.html">
#      <div class="title">
#       “Child Guard” Plastic Bag and Canister for Medications
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        excelsior / outer mission
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Drafting table">
#     <a href="https://sfbay.craigslist.org/scz/zip/d/santa-cruz-drafting-table/7714521653.html">
#      <div class="title">
#       Drafting table
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        santa cruz
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Small couch">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/san-rafael-small-couch/7714520370.html">
#      <div class="title">
#       Small couch
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san rafael
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Upper Left Control Arm 350z">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/el-sobrante-upper-left-control-arm-350z/7713214831.html">
#      <div class="title">
#       Upper Left Control Arm 350z
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        El Sobrante
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Micro USB Car Charger">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/el-sobrante-micro-usb-car-charger/7705881682.html">
#      <div class="title">
#       Micro USB Car Charger
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        El Sobrante
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Woven Laundry Basket">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-woven-laundry-basket/7714517912.html">
#      <div class="title">
#       Woven Laundry Basket
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        berkeley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Three picture frames">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/burlingame-three-picture-frames/7714516914.html">
#      <div class="title">
#       Three picture frames
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Burlingame
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="4 ft shop lamp">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/concord-ft-shop-lamp/7709517015.html">
#      <div class="title">
#       4 ft shop lamp
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Concord
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Oak chair">
#     <a href="https://sfbay.craigslist.org/scz/zip/d/soquel-oak-chair/7705079606.html">
#      <div class="title">
#       Oak chair
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        soquel
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Estate Sale,  Very big, 2 flats and garage - Now Free">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-estate-sale-very-big/7714515494.html">
#      <div class="title">
#       Estate Sale,  Very big, 2 flats and garage - Now Free
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        noe valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Desk with plenty of storage">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/campbell-desk-with-plenty-of-storage/7714514967.html">
#      <div class="title">
#       Desk with plenty of storage
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        campbell
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Queen matress">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/petaluma-queen-matress/7714514707.html">
#      <div class="title">
#       Queen matress
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        petaluma
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Chappywrap Blanket">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/burlingame-chappywrap-blanket/7714514479.html">
#      <div class="title">
#       Chappywrap Blanket
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Burlingame
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Black Bamboo Stakes (Phyllostachys Nigra)">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-black-bamboo-stakes/7714513552.html">
#      <div class="title">
#       Black Bamboo Stakes (Phyllostachys Nigra)
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        excelsior / outer mission
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="3 IKEA Kolbjorn Metal Shelves (unassembled)">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-ikea-kolbjorn-metal/7714513275.html">
#      <div class="title">
#       3 IKEA Kolbjorn Metal Shelves (unassembled)
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        marina / cow hollow
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Cherry wood bookcase - Free">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-cherry-wood-bookcase-free/7714512690.html">
#      <div class="title">
#       Cherry wood bookcase - Free
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        berkeley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Play Yard for Kids or Pets">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-play-yard-for-kids-or-pets/7714512536.html">
#      <div class="title">
#       Play Yard for Kids or Pets
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        marina / cow hollow
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Rawlings baseball helmet 6 1/4-6 7/8">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/dublin-rawlings-baseball-helmet/7704690348.html">
#      <div class="title">
#       Rawlings baseball helmet 6 1/4-6 7/8
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Dublin
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free plastic champagne flutes">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-plastic-champagne/7707544354.html">
#      <div class="title">
#       Free plastic champagne flutes
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Medela Pump in Style Breast Pump">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/cupertino-medela-pump-in-style-breast/7713192939.html">
#      <div class="title">
#       Medela Pump in Style Breast Pump
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Cupertino
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Life Insurance and Financial Planning Textbooks">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-life-insurance-and/7713051971.html">
#      <div class="title">
#       Life Insurance and Financial Planning Textbooks
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        excelsior / outer mission
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Hair Care Products, Deodorant">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-hair-care-products-deodorant/7714510842.html">
#      <div class="title">
#       Hair Care Products, Deodorant
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san jose east
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Animal Medications (for small dog under 10 lbs)">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-animal-medications-for/7713093216.html">
#      <div class="title">
#       Animal Medications (for small dog under 10 lbs)
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Solid Wood Hutch">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/san-bruno-solid-wood-hutch/7710920531.html">
#      <div class="title">
#       Solid Wood Hutch
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san bruno
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free 22” bike tube">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/pleasanton-free-22-bike-tube/7714508968.html">
#      <div class="title">
#       Free 22” bike tube
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        dublin / pleasanton / livermore
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="COVID tests (expired w/ extended shelf life)">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/sunnyvale-covid-tests-expired-extended/7714505353.html">
#      <div class="title">
#       COVID tests (expired w/ extended shelf life)
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        sunnyvale
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Co-Sleeper bedside bassinet and play yard">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/union-city-co-sleeper-bedside-bassinet/7714508053.html">
#      <div class="title">
#       Co-Sleeper bedside bassinet and play yard
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Union City
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="FREE BLENDER Waring Pro">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-blender-waring-pro/7714506823.html">
#      <div class="title">
#       FREE BLENDER Waring Pro
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Little Bench (PENDING)">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-little-bench-pending/7714506962.html">
#      <div class="title">
#       Little Bench (PENDING)
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        oakland downtown
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Chicco keyfit car seat &amp; car base (both EXPIRED): can use for trade in">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/sunnyvale-chicco-keyfit-car-seat-car/7714506798.html">
#      <div class="title">
#       Chicco keyfit car seat &amp; car base (both EXPIRED): can use for trade in
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        sunnyvale
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="stroller cup holder">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/union-city-stroller-cup-holder/7714506573.html">
#      <div class="title">
#       stroller cup holder
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Union City
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Gift Wrapping Paper, Bags, Boxes, Tissue Paper, Ribbons and Bows">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-gift-wrapping-paper-bags/7714506486.html">
#      <div class="title">
#       Gift Wrapping Paper, Bags, Boxes, Tissue Paper, Ribbons and Bows
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        excelsior / outer mission
#       </div>
#      </div>
#     </a>
#    </li>
# ...
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san rafael
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="FREE Snow car chain">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/redwood-city-free-snow-car-chain/7714370633.html">
#      <div class="title">
#       FREE Snow car chain
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        redwood shores
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Curtain Rod">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/pleasant-hill-curtain-rod/7714370346.html">
#      <div class="title">
#       Curtain Rod
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        concord / pleasant hill / martinez
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="A couple hanging lamps">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/sebastopol-couple-hanging-lamps/7710179092.html">
#      <div class="title">
#       A couple hanging lamps
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        sebastopol
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Tennis visor">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/pleasant-hill-tennis-visor/7714369338.html">
#      <div class="title">
#       Tennis visor
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        concord / pleasant hill / martinez
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title='Samsonite Luggage 12" Deep x 19" Wide x 29" Tall'>
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-samsonite-luggage-12-deep/7708264658.html">
#      <div class="title">
#       Samsonite Luggage 12" Deep x 19" Wide x 29" Tall
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        noe valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free desk">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/novato-free-desk/7713593337.html">
#      <div class="title">
#       Free desk
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        novato
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="ClosetMaid shelf track adjustable shelving system pieces">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-closetmaid-shelf-track/7714366622.html">
#      <div class="title">
#       ClosetMaid shelf track adjustable shelving system pieces
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Oakland
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Desktop">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/sunnyvale-desktop/7714365610.html">
#      <div class="title">
#       Desktop
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Sunnyvale
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Metal for scrape heavy engine, transmission etc">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/hayward-metal-for-scrape-heavy-engine/7714363792.html">
#      <div class="title">
#       Metal for scrape heavy engine, transmission etc
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        hayward / castro valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Disney Lion Guard toy structures">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-disney-lion-guard/7714362952.html">
#      <div class="title">
#       Free Disney Lion Guard toy structures
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Noe valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free pallet">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-pallet/7714362179.html">
#      <div class="title">
#       Free pallet
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco, Noe Valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Baby / Dog gate">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/benicia-baby-dog-gate/7714361573.html">
#      <div class="title">
#       Baby / Dog gate
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Benicia
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Standing lamp">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/vineburg-standing-lamp/7713417040.html">
#      <div class="title">
#       Standing lamp
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        sonoma
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Twin mattress set and frame">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/vineburg-twin-mattress-set-and-frame/7713409449.html">
#      <div class="title">
#       Twin mattress set and frame
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        sonoma
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Plantronics/Poly SAVI 440 wireless headset">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/pleasant-hill-plantronics-poly-savi-440/7714359749.html">
#      <div class="title">
#       Plantronics/Poly SAVI 440 wireless headset
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        concord / pleasant hill / martinez
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Samsung DVD / CD Player">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/pleasant-hill-samsung-dvd-cd-player/7713531924.html">
#      <div class="title">
#       Samsung DVD / CD Player
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        concord / pleasant hill / martinez
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Couch and recliners free,I'll give 50. To take">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/pittsburg-couch-and-recliners-freeill/7714356712.html">
#      <div class="title">
#       Couch and recliners free,I'll give 50. To take
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        concord / pleasant hill / martinez
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Flags Stand Wood &amp; Flag Staffs">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-flags-stand-wood-flag-staffs/7714355586.html">
#      <div class="title">
#       Flags Stand Wood &amp; Flag Staffs
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        berkeley north / hills
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Proform 590 Exercise Treadmill Perfect working order!">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-proform-590-exercise/7714355418.html">
#      <div class="title">
#       Proform 590 Exercise Treadmill Perfect working order!
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        castro / upper market
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="2 free wood pallets">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/camp-meeker-free-wood-pallets/7711666553.html">
#      <div class="title">
#       2 free wood pallets
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Camp Meeker
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Table 28” round cheery wood">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/castro-valley-table-28-round-cheery-wood/7714353829.html">
#      <div class="title">
#       Table 28” round cheery wood
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        hayward / castro valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Bosch Crockery Basket Dishwasher Rack">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/san-rafael-bosch-crockery-basket/7714353549.html">
#      <div class="title">
#       Bosch Crockery Basket Dishwasher Rack
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san rafael
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Oak dining table excellent condition">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/castro-valley-oak-dining-table/7714350890.html">
#      <div class="title">
#       Oak dining table excellent condition
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        hayward / castro valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Plant pots (6) and room divider">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/south-san-francisco-plant-pots-and-room/7714347682.html">
#      <div class="title">
#       Plant pots (6) and room divider
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        south san francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="King size headboard, custom-made">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/belvedere-tiburon-king-size-headboard/7705564077.html">
#      <div class="title">
#       King size headboard, custom-made
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Belvedere Tiburon
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free stuff you didn't know you needed">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-free-stuff-you-didnt-know-you/7714343448.html">
#      <div class="title">
#       Free stuff you didn't know you needed
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        berkeley north / hills
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Dirt Vallejo Area only">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/vallejo-free-dirt-vallejo-area-only/7714340456.html">
#      <div class="title">
#       Free Dirt Vallejo Area only
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        east bay area
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Clean Dirt Available">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/redwood-city-free-clean-dirt-available/7714340656.html">
#      <div class="title">
#       Free Clean Dirt Available
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        peninsula
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="desk tops">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-desk-tops/7705755506.html">
#      <div class="title">
#       desk tops
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san jose east
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="1937 kitchen drawers">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-1937-kitchen-drawers/7709427760.html">
#      <div class="title">
#       1937 kitchen drawers
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Oakland
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Cosco scenera travel car seat">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-cosco-scenera-travel-car/7714337255.html">
#      <div class="title">
#       Cosco scenera travel car seat
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        noe valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Large couch boxes NEW">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-large-couch-boxes-new/7714331817.html">
#      <div class="title">
#       Large couch boxes NEW
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        berkeley north / hills
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Kale seed. Smooth leaf. 40 years acclimated to San Lorenzo">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/san-lorenzo-free-kale-seed-smooth-leaf/7710884070.html">
#      <div class="title">
#       Free Kale seed. Smooth leaf. 40 years acclimated to San Lorenzo
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        hayward / castro valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="FREE Jerusalem Artichoke tubers for planting.">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/san-lorenzo-free-jerusalem-artichoke/7707145910.html">
#      <div class="title">
#       FREE Jerusalem Artichoke tubers for planting.
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        hayward / castro valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Fig tree cuttings. I have plenty left.">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/san-lorenzo-free-fig-tree-cuttings-have/7705561915.html">
#      <div class="title">
#       Free Fig tree cuttings. I have plenty left.
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        hayward / castro valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free . Scrap aluminum. Free! San Lorenzo.">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/san-lorenzo-free-scrap-aluminum-free/7714320960.html">
#      <div class="title">
#       Free . Scrap aluminum. Free! San Lorenzo.
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        hayward / castro valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Book">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/concord-book/7714320253.html">
#      <div class="title">
#       Book
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        walnut creek
#       </div>
#      </div>
#     </a>
#    </li>
#   </ol>
#  </body>
# </html>

# %% [markdown]
# What selector to grab the links:
# 1. Looking at the results above, I would be selecting the list ('li') element with the class of 'cl-static-search-result', and then select the anchor ('a') element and get 'href'.
# 2. Another way is to select the 'div' element with the class 'title', and select their parents(which are the anchors), then finally get 'href'.

# %%
# find the listing url
listings = soup.select('li.cl-static-search-result > a')

# create an empty list
listing_url = []

# write a loop to extract 250 listings and save them to a list
for i in range(250):
    listing_url.append(listings[i].get('href'))
    
listing_url
# Out:
# ['https://sfbay.craigslist.org/eby/zip/d/el-cerrito-bolster-pillow/7714551361.html',
#  'https://sfbay.craigslist.org/eby/zip/d/ankle-foot-medical-cam-boots-unisex/7714551359.html',
#  'https://sfbay.craigslist.org/nby/zip/d/santa-rosa-nice-sleeper-sofa/7710871185.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-unopened-baby-diaper-ointment/7713234275.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-clearlax-miralax-generic/7713208049.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-two-drawer-file-cabinet/7714549739.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-free-outdoor-tiles/7714549146.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-nightstand/7714549199.html',
#  'https://sfbay.craigslist.org/eby/zip/d/san-lorenzo-free-futon-mattress-72x52/7706646621.html',
#  'https://sfbay.craigslist.org/nby/zip/d/novato-four-kitchen-chairs/7713913055.html',
#  'https://sfbay.craigslist.org/eby/zip/d/fremont-free-and-great-condition-cal/7714546351.html',
#  'https://sfbay.craigslist.org/pen/zip/d/belmont-garage-cabinets/7714546515.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-free-10-waterproof-id-badge/7714546254.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-wooden-glider-rocking/7714546001.html',
#  'https://sfbay.craigslist.org/eby/zip/d/el-cerrito-free-garden-wall-cinderblocks/7714545180.html',
#  'https://sfbay.craigslist.org/eby/zip/d/el-cerrito-free-cabinet-organizers/7714545164.html',
#  'https://sfbay.craigslist.org/eby/zip/d/el-cerrito-free
html',
#  'https://sfbay.craigslist.org/eby/zip/d/alameda-la-boy-urban-attitudes-carlyle/7714438251.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-hp-colorjet-2605dn-for-parts/7714437197.html',
#  'https://sfbay.craigslist.org/eby/zip/d/san-leandro-free-wood-etc-from-kitchen/7714437103.html',
#  'https://sfbay.craigslist.org/pen/zip/d/stanford-free-vintage-tack-box-wall/7714437085.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-bits-and-bobs/7714435921.html',
#  'https://sfbay.craigslist.org/sby/zip/d/sunnyvale-corner-computer-desk/7714435381.html',
#  'https://sfbay.craigslist.org/scz/zip/d/boulder-creek-free-trampoline-10/7714434867.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-hanger-from-french-line-liberte/7714433430.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-new-medical-convalescent-equip/7714433007.html',
#  'https://sfbay.craigslist.org/eby/zip/d/concord-sugar/7713476050.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-carlos-hp-laserjet-pro-400-m401/7714432214.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-vintage-hotel-give-aways/7714432158.html',
#  'https://sfbay.craigslist.org/eby/zip/d/brentwood-wall-clock/7707822463.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-yellow-gari/7714431142.html',
#  'https://sfbay.craigslist.org/eby/zip/d/brentwood-comfy-recliner/7707816009.html',
#  'https://sfbay.craigslist.org/eby/zip/d/brentwood-free-cali-bullets-black-ops/7709834671.html',
#  'https://sfbay.craigslist.org/sby/zip/d/san-jose-queen-size-mattress-cover/7714430819.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-tiny-pill-boxes/7714430250.html',
#  'https://sfbay.craigslist.org/pen/zip/d/san-mateo-free-mahjong-poker-chinese/7714429617.html',
#  'https://sfbay.craigslist.org/eby/zip/d/alameda-free-heater-filters/7714429176.html',
#  'https://sfbay.craigslist.org/nby/zip/d/petaluma-sonoma-county-vintage-visitors/7714428428.html',
#  'https://sfbay.craigslist.org/eby/zip/d/walnut-creek-15-heavy-duty-pallets-free/7714427624.html',
#  'https://sfbay.craigslist.org/eby/zip/d/emeryville-free-baby-things/7714427235.html',
#  'https://sfbay.craigslist.org/sby/zip/d/gilroy-office-desk-cabinets/7709469262.html',
#  'https://sfbay.craigslist.org/eby/zip/d/el-cerrito-mostly-childrens-dvds/7714424146.html',
#  'https://sfbay.craigslist.org/eby/zip/d/berkeley-free-on-curb-double-pane-window/7714423952.html',
#  'https://sfbay.craigslist.org/scz/zip/d/redwood-estates-coffee-table-side-piece/7714423059.html',
#  'https://sfbay.craigslist.org/nby/zip/d/santa-rosa-55-gallon-drums/7712789601.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-queen-aerobed-air/7713089936.html',
#  'https://sfbay.craigslist.org/nby/zip/d/sausalito-bike-rack-for-car/7714421513.html',
#  'https://sfbay.craigslist.org/sby/zip/d/santa-clara-lamp/7714420130.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-step-stool-water-cube/7714421201.html',
#  'https://sfbay.craigslist.org/sby/zip/d/santa-clara-wooden-chairs/7714420998.html',
#  'https://sfbay.craigslist.org/eby/zip/d/oakland-car-audio-ground-loop-noise/7714419996.html',
#  'https://sfbay.craigslist.org/scz/zip/d/freedom-wood-desk/7714419923.html',
#  'https://sfbay.craigslist.org/pen/zip/d/redwood-city-commercial-and-household/7714415886.html',
#  'https://sfbay.craigslist.org/eby/zip/d/martinez-free-flower-vases/7714414681.html',
#  'https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-canopy-awnings/7712840470.html']

# %% [markdown]
# Explanation: The URL automatically returns 360 listings, so I simply write a for loop to extract the first 250 links

# %%
# 5. Save HTML Pages
import re

time.sleep(5) # add delay of 5 seconds

for x in range(250):
    # get the new url
    url_new = listing_url[x]
    page_new = requests.get(url_new, headers = headers)
    soup_new = BeautifulSoup(page_new.content)
    
    # find the listing id
    temp = str(soup_new.find('div',class_='postinginfos'))
    pattern = r'\d{9,11}' # find the continuous digits within the returned piece of html
    listing_id = re.findall(pattern, temp)[0]
    
    # Name the file with listing id
    file_name = f"{listing_id}.html"
    
    # write in the html file
    f = open(file_name, "w", encoding='utf-8')
    f.write(str(soup_new))
    f.close()
    
    time.sleep(5) # add delay of 5 seconds

# %% [markdown]
# ## Part 2: Parsing and Displaying Information from Saved HTML

# %%
# 1. Read Saved HTML Files
import os,sys

# Loop through each file in the directory

for filename in os.listdir('HTML Files'):

    # Check if the file ends with .html
    if filename.endswith(".html"):

        # Construct the full file path
        filepath = os.path.join('HTML Files', filename)

        # Read file to string
        file = open(filepath, 'r', encoding='utf-8')
        html = file.read()
        soup2 = BeautifulSoup(html, 'lxml')
        
        # Find title
        title = soup2.select('title')
        title_print = title[0].text[:-25]
        print('\033[1mTitle:\033[0m', title_print)
        
        # Find image URL
        img_url = str(soup2.select_one('img[src]'))
        #pattern_2 = r'[/:._a-zA-Z0-9]*.jpg'
        #img_url_print = re.findall(pattern_2, img_url)[0]
        
        if img_url != 'None':
            pattern_2 = r'[/:._a-zA-Z0-9]*.jpg'
            img_url_print = re.findall(pattern_2, img_url)[0]
            print(img_url_print)
            
        else:
            print("Image URL not found")
        
        # Find description
        description = soup2.select('section #postingbody')
        description_print = description[0].text[30:]
        print(description_print)
        
        # Find Post ID (similar to the listing id from above)
        post_id = str(soup2.select_one('div.postinginfos > p'))
        pattern = r'\d{9,11}' # find the continuous digits
        post_id_print = re.findall(pattern, post_id)[0]
        print('Post ID: ',post_id_print)
        
        # Find Posted Date
        post_date = soup2.find_all('p',class_ = 'postinginfo reveal')
        print(post_date[1].text)
        
        # Find Updated Date, if no update yet, return no update yet
        updated_date = soup2.find_all('p',class_ = 'postinginfo reveal')
        if len(updated_date) >= 3:
            print(updated_date[2].text)
        else:
            print("No update yet")
                
        print() #add a space between each listing for better readability
# Out:
# Title: Rawlings baseball helmet 6 1/4-6 7/8
# https://images.craigslist.org/00p0p_hZSMbBjPoJT_0tE0CI_600x450.jpg
# Used two seasons in little league
#
# Rawlings baseball helmet 6 1/4-6 7/8
#
# Post ID:  7704690348
# posted: 2024-01-05 19:19
# updated: 2024-02-04 17:35
#
# Title: Oak chair
# https://images.craigslist.org/00n0n_baDAS4segUc_0t20CI_600x450.jpg
# Swivels, height adjusts, great condition
#
# Post ID:  7705079606
# posted: 2024-01-07 06:58
# updated: 2024-02-04 17:51
#
# Title: Micro USB Car Charger
# https://images.craigslist.org/00v0v_coblI9aG3YU_0t20CI_600x450.jpg
# Don't need this
#
# Post ID:  7705881682
# posted: 2024-01-09 12:45
# updated: 2024-02-04 18:09
#
# Title: FREE Istanbul Metro Card
# https://images.craigslist.org/00h0h_lM7qn9s6Spm_0t20CI_600x450.jpg
# Might be some money left on it, not sure.
#
# Post ID:  7706359982
# posted: 2024-01-10 22:00
# updated: 2024-02-04 19:20
#
# Title: Free beautiful antique twin bed frame
# https://images.craigslist.org/00J0J_anTNI7LgRnq_0CI0t9_600x450.jpg
# Free.  Really nice, beautiful wood antique bed frame.  Free to the first person who can pick it up
#
# Post ID:  7706573192
# posted: 2024-01-11 12:54
# updated: 2024-02-04 19:07
#
# Title: Free futon mattress 72”x52” (mattress only)
# https://images.craigslist.org/00W0W_gJDoIlsCV5_0lM0CI_600x450.jpg
# A little faded but nothing too crazy. No weird stains or smells. Soft but not too soft(like it’ll hold its shape, you won’t sink in).
#
# Looks kinda weird without the cover due to the creases. I’ll include the cover but it does have 3 small holes in it.
#
# Mattress only!!
#
#
# Post ID:  7706646621
# posted: 2024-01-11 16:37
# updated: 2024-02-04 21:43
#
# Title: Specialized Road Bike Shoes size 46, USED
# https://images.craigslist.org/00C0C_cCNkUXj0bfU_0CI0t2_600x450.jpg
# A pair of well used Specialized Road Bike Shoes with well used Speedplay clips attached, size 46. Did I say well used? But, free to a good home! Size label inside says EU 46, US 11.5-12, UK 10.5-11.
#
# Please leave a cell tel number if you are seriously interested.
#
# Thanks for looking!
#
# Post ID:  7707034031
# posted: 2024-01-12 20:27
# updated: 2024-02-04 20:40
#
# Title: free kimball piano
# Image URL not found
#
# One front leg is missing the wheel but can be replaced and is stable without this.
#
# Post ID:  7707298671
# posted: 2024-01-13 15:55
# updated: 2024-02-04 15:41
#
# Title: Free pregnancy pillow
# https://images.craigslist.org/01414_eAyaugOCcjG_1320MM_600x450.jpg
# U shaped, worked great for me. https://www.amazon.com/gp/product/B09LQWCJMG/ref=ppx_yo_dt_b_search_asin_title?ie=UTF8&psc=1
#
# Post ID:  7707497306
# posted: 2024-01-14 11:45
# updated: 2024-02-04 19:20
#
# Title: Free plastic champagne flutes
# https://images.craigslist.org/00O0O_7kF84lEizn6_0t20CI_600x450.jpg
# Heavyweight plastic, one piece plastic champagne flutes. 10 pieces.
#
# Friends brought these to the hospital to celebrate with us when we had a baby. Only used them once and they’ve been in a storage for a bit so they likely need a run through the dishwasher. But great heavy duty plastic that can be reused without worry of breaking nice glasses at a party!
#
# Post ID:  7707544354
# posted: 2024-01-14 14:14
# updated: 2024-02-04 17:34
#
# Title: Comfy recliner
# https://images.craigslist.org/00303_b6yHi33qoUZ_0t20CI_600x450.jpg
# Very comfy recliner chai. Cozy and soft, an old fav here that is being replaced. Reclines and is in good condition. Wait till you sit in it.
# Contact jeff in Brentwood at 408-5o6-4274
#
# Post ID:  7707816009
# posted: 2024-01-15 11:38
# updated: 2024-02-04 12:55
#
# Title: Wall clock
# https://images.craigslist.org/00S0S_jHeu8M8advW_0t20CI_600x450.jpg
# Free wall clock
# Jeff in Brentwood at 408-5o6-4275
#
# Post ID:  7707822463
# posted: 2024-01-15 11:53
# updated: 2024-02-04 12:55
#
# Title: Used artificial grass and Sand (only sand, grass is gone)
# https://images.craigslist.org/00G0G_aY25LQz1rfw_0CI0lN_600x450.jpg
# FREE FREE
#
# GRASS IS GONE
# GRASS IS GONE
# GRASS IS GONE
#
# There is sand and gravel below it which is also free if anyone needs it. It's about 10 feet by 2 feet and about 5 inches deep in the ground. Location is Riedel Rd, San Jose CA.
#
#
# Free, Garden, Sand, Gravel, Grass, South Bay, Bay area, Landscape, Sod
#
# Post ID:  7708883310
# posted: 2024-01-18 14:06
# updated: 2024-02-04 20:40
#
# Title: Office desk w/ cabinets
# https://images.craigslist.org/00u0u_5DmmHmriyCd_0CI0t2_600x450.jpg
# Cherry wood solid office desk
#
# My father paid $20k 15 years ago
#
# Very solid
#
# Approximately 8’ x 8’
#
# Post ID:  7709469262
# posted: 2024-01-20 09:59
# updated: 2024-02-04 12:39
#
# Title: 4 ft shop lamp
# https://images.craigslist.org/00z0z_4mGrtisXYgS_0CI0l6_600x450.jpg
# Light works but after about 30 minute, it shuts off for 5 to 10 minutes, then the light turns back on
# Comes with hangers
# No bulbs included
# posted: 2024-01-24 19:33
# updated: 2024-02-04 15:10
#
# Title: Vitamaster Triumph Treadmill
# https://images.craigslist.org/00B0B_6z2E2YqIFz5_0t20CI_600x450.jpg
# Older model but still works fine.  Inclines up to 15 degrees.
#
# Post ID:  7711309600
# posted: 2024-01-25 20:01
# updated: 2024-02-04 15:13
#
# Title: Free Big Lot Of Genuine OEM Dell PowerEdge R620 Server Spare Parts
# https://images.craigslist.org/00R0R_dU8YAxYunsA_0CD0t2_600x450.jpg
# This listing is for a Free Big Lot Of Genuine OEM Dell PowerEdge R620 Server Spare Parts in the images shown. These parts are for use with Dell PowerEdge R620 servers. They were stored in a IT closet. The parts all appear to be in good condition but they are untested as I don't have a PowerEdge R620 available to test them.
#
# I am located in Antioch
#
#
#
# Here is what's included:
#
# 9 SAS dat cables - D/PN WVF6J
#
# 1 Four drive SAS / SATA backplane - D/PN PMHHG
#
# 1 System Fan - D/PN 2X0NG
#
# 1 CPU heatsink -  M112P
#
# 4 Control panel with LCD screen
#
# 3 Optical drive bay inserts - D/PN 1CVCG
#
# 3 PCIe Backplanes - D/PN VKHCN
#
# 2 PCIe Backplanes - D/PN N9YDK
#
# 6 SATA optical drive cables with power leads - D/PN TY09P
#
# Post ID:  7711552921
# posted: 2024-01-26 13:34
# updated: 2024-02-04 15:48
#
# Title: Free Stuff
# https://images.craigslist.org/00W0W_dEPi7rnJAY5_0CI0t2_600x450.jpg
# Random free stuff!
#
# - Girl's one size Peruvian style beanie
# - Women's watch, not working, could just need a new battery
# - (5) Injustice Game Character Cards - Series 3
# (Taken) - LED rechargeable hanging light bulb for tent, charge light comes on, but doesn't turn on
# - Black plastic steering wheel cover
#
# Post ID:  7711572302
# posted: 2024-01-26 14:29
# updated: 2024-02-04 19:20
#
# Title: Two Poinsettas
# https://images.craigslist.org/00B0B_6ofUzb7x4yt_0MM132_600x450.jpg
# I have two pointsettas from the Christmas season.  I have kept them indoors, but they are slowly losing their leaves.  I am willing to give them to someone who can better care for them.  They are about 2 to 2 1/2 feet tall.
#
# Post ID:  7711761947
# posted: 2024-01-27 08:52
# updated: 2024-02-04 17:05
#
# Title: FREE American Standard Toilet
# https://images.craigslist.org/01515_qBgHChNwuH_07K0ak_600x450.jpg
# We have an American Standard Champion series toilet to give away.
#
# Over all very clean and works great, but, it developed a hairline crack in the tank which slightly leaks.
#
# You can replace the tank alone for half the cost of the toilet, or likely seal it with some silicone glue.
#
# Thought I'd see if anyone was interested before bringing it to the dump.
#
# Thanks!
#
# Post ID:  7711920009
# posted: 2024-01-27 16:12
# updated: 2024-02-04 18:31
#
# Title: Desk hutch
# https://images.craigslist.org/01212_1saoQwBgc9e_0t20CI_600x450.jpg
# Desk hutch
# 70x42x13
#
# Post ID:  7712015602
# posted: 2024-01-28 06:36
# updated: 2024-02-04 14:26
#
# Title: Non working chest freezer
# https://images.craigslist.org/00D0D_bb0FOETletO_0CI0t2_600x450.jpg
# Hisense 7.0 cu ft. It's about 5 years old. Just stopped. Yours for free, if you're handy, it's probably the relay or the thermostat that conked out. I don't have the time to troubleshoot.
#
# Free pickup only. I can help you load. Will fit in minivan easily. Pickup truck obviously
#
# https://youtu.be/zEsj1y2Q_8o?si=7HKrmjjH3VQC8xXW
#
# Post ID:  7712074474
# posted: 2024-01-28 09:51
# updated: 2024-02-04 19:45
#
# Title: Swap cooler / Evaportavie Cooler Pads - Free
# https://images.craigslist.org/00a0a_6NtCiN9OSIo_0cj0q0_600x450.jpg
# Swap cooler / Evaportavie Cooler Pads Replacement - Free. Description on pic.
#
# Post ID:  7712143420
# posted: 2024-01-28 13:14
# updated: 2024-02-04 13:45
#
# Title: Free clay dirt, take as much as you want!
# https://images.craigslist.org/01111_8f7M0tmHTwb_0CI0A5_600x450.jpg
# I have multiple cubic yards of free clay dirt ready for you to come pick up and take home with you. If you have a bobcat, you can scoop up as much as you would like.
#
# Uses of Clay Soil
#
# Farming
# The particle of clay soil is compact in nature hence it tends to not old enough air which is the basic requirement of many plants.
#
# Construction
# Since ancient times, clay soil has been used for construction because of its extraordinary properties.
#
# Gardening
# Good nutrient density: Clay soil particles attract and bind to nutrients like calcium, magnesium, and potassium that feed plants and help them grow. The innate clay minerals also make for a healthy vegetable garden bed.
#
# Ceramics
#
# Pottery
#
# Medicinal
#
# Post ID:  7712204736
# posted: 2024-01-28 17:14
# updated: 2024-02-04 17:08
#
# Title: Free two pool lounge chairs & table
# https://images.craigslist.org/00S0S_i7TVBnn3E0e_0CI0t2_600x450.jpg
# Recently power washed and in good shape.
#
# Post ID:  7712213645
# posted: 2024-01-28 17:58
# updated: 2024-02-04 15:14
#
# Title: Handmade Display Cabinet
# https://images.craigslist.org/00u0u_lVp5KrQIQh6_0t20CI_600x450.jpg
# Handmade by artisans in Brazil or Ecuador in the late 60s or early 70s (parents living/working abroad at the time and can’t remember exactly when/where they got it). The craftsmanship is incredible. In excellent shape as it was only used as a display and storage cabinet in a formal dining room. Comes with some detached wheels that we are not sure if they belong with the cabinet, but figure we should include them in case.
#
# Post ID:  7712222572
# posted: 2024-01-28 18:49
# updated: 2024-02-04 15:31
#
# Title: Mirror 5' x 3’ 7”
# https://images.craigslist.org/00J0J_3fIh7sP7AV1_0CI0t2_600x450.jpg
# Taken down from bathroom in remodel. Some water spots on very bottom 1/2" but can be covered up or cut off.  Otherwise great shape.
#
# Phone calls only.
#
# Post ID:  7712404017
# posted: 2024-01-29 10:35
# updated: 2024-02-04 16:18
#
# Title: Cooler (45-ish quart capacity)
# https://images.craigslist.org/00s0s_ctEHEriuLFy_0Cz0t2_600x450.jpg
# Free cooler with wheels. I think it has ~45 quart capacity as the internal space looks about the same as my new cooler. This cooler works and will get the job done but it is old/used. There is a crack in the casing where the handle attaches (see attached picture). Let me know if you are interested and I can provide the pickup address.
#
# Post ID:  7712477234
# posted: 2024-01-29 13:27
# updated: 2024-02-04 13:50
#
# Title: Shower sliding door with hardware
# https://images.craigslist.org/00303_f9kFpFuEpxx_0lM0CI_600x450.jpg
# Removed our bath’s sliding shower door. It has two textured glass doors, a bottom rail, a top rail, and two side rails. 58.25” wide total. Each door is 29.25” X 55.5”.
# Text, call, or email me.
#
# isaacwfreestuffsf
#
# Post ID:  7713154629
# posted: 2024-01-31 13:52
# updated: 2024-02-04 16:43
#
# Title: Humidifier - Holmes
# https://images.craigslist.org/00505_jEcG8obzvX8_0CI0t2_600x450.jpg
# Free working Holmes humidifer.  As seen in the picture there is a broken plastic piece; however, some super glue should easily fix it.
#
# Checkout the other stuff I'm giving away for free here: https://sfbay.craigslist.org/search/sss?query=isaacwfreestuffsf
#
# No holding unless I talked with you and you are on your way within the hour.
#
# Text, call, or email me.
#
# isaacwfreestuffsf
#
# Post ID:  7713160483
# posted: 2024-01-31 14:08
# updated: 2024-02-04 16:43
#
# Title: Free Gravel and sand
# https://images.craigslist.org/00606_ib7JlE3Aeqr_0MM132_600x450.jpg
# I removed some of the artificial grass. There is gravel and sand below it which I want to give away for free. It's about 10 feet by 2 feet wide space with gravel about 5 inches deep.
#
# About three wheelbarrows approximately. The location is near EVERGREEN ELEMENTARY SCHOOL.
#
# Thanks
#
#
# Garden, Backyard, Landscape, Artificial grass.
#
# Post ID:  7713184817
# posted: 2024-01-31 15:26
# updated: 2024-02-04 20:44
#
# Title: Medela Pump in Style Breast Pump
# https://images.craigslist.org/00I0I_etnuCK104LT_0t20CI_600x450.jpg
# Medela Pump in Style breast pump
# Only used periodically for 3 months
# Comes with car adapter
#
#
# Post ID:  7713192939
# posted: 2024-01-31 15:56
# updated: 2024-02-04 17:33
#
# Title: ClearLax (MiraLax generic )
# https://images.craigslist.org/00v0v_LZkKI28ztj_0k30t2_600x450.jpg
# ClearLax (MiraLax generic)
# Laxative powder. Works like a charm.
#
#
# Post ID:  7713208049
# posted: 2024-01-31 16:52
# updated: 2024-02-04 22:07
#
# Title: Upper Left Control Arm 350z
# https://images.craigslist.org/00Y0Y_jFOyE0XQN11_0CI0t2_600x450.jpg
# Getting rid of this extra control arm.
#
# Post ID:  7713214831
# posted: 2024-01-31 17:16
# updated: 2024-02-04 18:09
#
# Title: Unopened Baby Diaper Ointment
# https://images.craigslist.org/00R0R_8iR6Y0QskrL_0iQ0t2_600x450.jpg
# Baby Diaper Ointment
# Unopened
# 6 oz tube.
#
# Post ID:  7713234275
# posted: 2024-01-31 18:53
# updated: 2024-02-04 22:07
#
# Title: Bag of crayons
# https://images.craigslist.org/00d0d_lrGG2yC0azo_0MM132_600x450.jpg
# Bag of crayons
#
# Contact phone number is required for a reply  - thanks
#
# Post ID:  7713466445
# posted: 2024-02-01 13:03
# updated: 2024-02-04 18:47
#
# Title: Sugar
# https://images.craigslist.org/00T0T_6UdQTf6FfP1_0CI0t2_600x450.jpg
# (New/Unopened) 1 lb. Bag of Powdered Sugar  -  Exp. Apr. 28, '25
#
#
# From a non-smoking, no pets home.
#
#
# Call (925) 603-FREE  [3733]
#
# Post ID:  7713476050
# posted: 2024-02-01 13:25
# updated: 2024-02-04 13:00
#
# Title: Working treadmill
# https://images.craigslist.org/00v0v_kDH9hJRw6SV_0t20CI_600x450.jpg
# Downsizing it’s a great machine
#
# Post ID:  7713710571
# posted: 2024-02-02 09:17
# No update yet
#
# Title: Bits and bobs
# https://images.craigslist.org/00h0h_6aMH3aXCCGm_0cA0gM_600x450.jpg
# Assorted bits and bobs: Infant of Prague medal; Sheffield steel blade with Bakelite (?) handle; polished stone; buttons; etc.
#
# Post ID:  7714435921
# posted: 2024-02-04 13:09
# No update yet
#
# Title: Free vintage tack box - wall mount
# https://images.craigslist.org/00l0l_7XWf67Ge83V_0MM132_600x450.jpg
# Vintage tack box, sturdy wood, excellent condition
# designed to mount on wall to keep brushes, wraps, accessories etc at eye level.  Can also sit on the ground.
# 24 inches long, 10.5 inches wide, 18 inches tall
#
# pickup near Stanford campus
#
# Post ID:  7714437085
# posted: 2024-02-04 13:12
# No update yet
#
# Title: Free wood etc from kitchen and bath remodel
# https://images.craigslist.org/00404_ctErdpoFPYK_0CI0t2_600x450.jpg
# Free! Come pick any wood, sinks, cabinets, etc. from our remodel. It all goes in the dumpster on Tuesday.
#
# We are in Castro Valley on Remco Street near Petersen Way. We aren’t responding to emails from this post, just come pick it up. We will update and remove the post as items are picked up.
#
# Post ID:  7714437103
# posted: 2024-02-04 13:12
# No update yet
#
# Title: Hp colorjet 2605dn for parts or repair
# https://images.craigslist.org/00I0I_b5LbacMxGDw_0lM0CI_600x450.jpg
# Hp colorjet laser color printer for parts or repair.
# It prints, but has colour streaks on the page. Has a extra magenta cartridge which seems to be leaking too. There are videos on YouTube on fixing cartridges.
#
# Could be useful for someone who needs parts.
#
# Free
#
# Post ID:  7714437197
# posted: 2024-02-04 13:12
# No update yet
#
# Title: La Z Boy Urban Attitudes Carlyle High Leg Recliner
# https://images.craigslist.org/00u0u_5lU6u6YMWcA_0DF0MW_600x450.jpg
# Brown mahogany arms with beige chenille fabric, seen better days looks-wise, but still comfortable and substantial. Pushback recliner supports reclined position as show in the one photo and reclined flat position for napping. Recently replaced and we don't have room to keep both. Delivery negotiable
#
# Post ID:  7714438251
# posted: 2024-02-04 13:15
# No update yet
#
# Title: Women’s clothing - good condition
# https://images.craigslist.org/00M0M_aMtuEI5P7nn_0CI0t2_600x450.jpg
# Two bags of women’s clothing. Size s-m. I’m a size 6. Good condition, mix of stuff. T-shirts, jumpsuits, flannel, etc. Come pick up today near mission & precita.
#
# Text don’t email
#
# Post ID:  7714439336
# posted: 2024-02-04 13:18
# No update yet
#
# Title: Free ceiling fan. Fully functional, in great shape.
# https://images.craigslist.org/00101_a3SpnjJJO8M_0sF0CI_600x450.jpg
# Switched out our ceiling lighting in our bedroom, free ceiling fan first-come-first-serve. Located in Rockridge.
#
# Post ID:  7714439415
# posted: 2024-02-04 13:18
# No update yet
#
# Title: BLOOD GLOUCOSE MONITOR SYSTEM New, not opened
# Image URL not found
# Come pick up at my house in Petaluma on Peta. Blvd. South
#    across from warehouses
# show contact info
#  NO Morning calls,
#  NO e-mail/No Text; this is a Land Line.
#
# Post ID:  7714440682
# posted: 2024-02-04 13:22
# No update yet
#
# Title: Bike Bags, you need to have a rack on bicycle. to use these.
# Image URL not found
# Call for details  show contact info
#  Land Line
# No Morning calls, But Ok to call til 11:00 in the Evening.
# No e-mail leave msg. on voice mail.
# Petaluma Blvd. South across from warehouses. Call to pick up.
# These are for bicycle, not motorcycle.
#
# Post ID:  7714440939
# posted: 2024-02-04 13:23
# No update yet
#
# Title: BAG OF MASKS: Many colors, patterns, most cotton, new.......
# Image URL not found
# or worn a couple of times and washed by hand (not w/ other laundry.)
# Come get the entire bag.  I am on south end of Petaluma Blvd. across from
# Warehouses. Cross st. is I and J but J does not cross the Boulevard.
# Call  show contact info
#  Land Line, leave voice msg. NO e-mail.
# NO Morning calls, even just to leave msg. I will not answer morning calls.
#
# Post ID:  7714441108
# posted: 2024-02-04 13:24
# No update yet
#
# Title: Scrap Wood 2x4 Studs
# https://images.craigslist.org/00L0L_9C9v5QaXM21_0t90CI_600x450.jpg
# Five 2x4x8 studs plus one shorter about 6'.
# One 4x6x3 header.
#
# Okay shape suitable for reuse. Plenty of nail holes and mostly all nails pulled.
#
# Post ID:  7714442491
# posted: 2024-02-04 13:28
# No update yet
#
# Title: Free tote bags
# https://images.craigslist.org/00S0S_1P1GpDt8Bg_0lM0CI_600x450.jpg
# Assorted tote bags - all clean and lightly used. Some canvas, some packable nylon, one insulated. All free!
#
# Post ID:  7714442942
# posted: 2024-02-04 13:29
# No update yet
#
# Title: White Shelves
# https://images.craigslist.org/00E0E_aTporXcRj9s_07K0ak_600x450.jpg
# Free white shelves
# 42"h x 31.5"w x 11"d
# They are clean and in good shape.
# Post ID:  7714443784
# posted: 2024-02-04 13:32
# No update yet
#
# Title: KEEP YOUR STUFF DRY: plastic bags. Lg. sheets of plastic, ect.
# Image URL not found
# come see, and pick up at my place on Petaluma Blvd, south
# across from warehouses just past stop light at I st.
# show contact info
#  Land Line
# NO e-mail NO Morning calls, even just to leave msg.
# But OK to call evenings til 11:00
#
# Post ID:  7714444144
# posted: 2024-02-04 13:33
# No update yet
#
# Title: Free Drop-in Bathtub Available
# https://images.craigslist.org/00M0M_3QnUKvJ76O1_0oR0CI_600x450.jpg
# Are you in the process of remodeling your bathroom, searching for that perfect centerpiece for your home spa, or looking for a project that inspires your creativity? We have an exciting offer for you: a free drop-in bathtub waiting to be the highlight of your next home improvement project.
#
# What’s Available?
# One Drop-in Bathtub: This bathtub is a generous size, perfect for soaking and relaxation, and ready to be integrated into your bathroom design. It's a fantastic find for anyone wanting to add a touch of luxury to their home without the luxury price tag.
#
# Pickup Only: You will need to arrange your own transportation for the bathtub.
#
# Team Lift: The bathtub is substantial and requires at least two people for safe handling and transportation. Please come prepared to ensure a smooth pickup.
#
# Post ID:  7714445485
# posted: 2024-02-04 13:37
# updated: 2024-02-04 19:21
#
# Title: Cordline to cover and conceal wires BRAND NEW
# https://images.craigslist.org/00r0r_k06akBZ2hvz_0t20CI_600x450.jpg
# Cordline to cover and conceal wires and cords. Brand new. Box never opened. Free.
#
# Instructions: Please only reach out when you’re ready to come pick up. Marina district. Text or email with the time you’ll be coming by.  show contact info
#  Thanks!
#
# Post ID:  7714446042
# posted: 2024-02-04 13:39
# Here is the shed: https://www.wayfair.com/storage-organization/pdp/walsunny-6-ft-w-x-4-ft-d-metal-traditional-storage-shed-wlsy3749.html
#
# I need this gone by Saturday, Feb 10.
#
# It's 6 months old, doesn't leak, and is 4' deep by 6' wide, roughly 5' tall.
#
# Call or text me, do not email me.
#
# Post ID:  7714542844
# posted: 2024-02-04 20:48
# updated: 2024-02-04 22:04
#
# Title: Free area rugs
# https://images.craigslist.org/00l0l_bN2cbrm8Y45_0t20CI_600x450.jpg
# Two free area rugs available.
#
# Gray and white color dimensions are approx 12’x9’
#
# Cream/beige color dimensions are approx 6.5’x10’
#
# Please email me to arrange for pickup.
#
# Post ID:  7714542941
# posted: 2024-02-04 20:49
# No update yet
#
# Title: Moving Boxes - Small, Medium and Large
# https://images.craigslist.org/00o0o_8souVPhbDIW_0t20CI_600x450.jpg
# Big bunch of home depot moving boxes, used only once. There's at least 20 boxes - must take ALL of the boxes.
#
# Multiple sizes - small, medium and large.
#
# Post ID:  7714543953
# posted: 2024-02-04 20:59
# No update yet
#
# Title: IKEA book shelf
# https://images.craigslist.org/00g0g_hM5tqXGRGXq_0ak07L_600x450.jpg
# IKEA wood file cabinet/shelf.  It is in good condition with some damage to the back corner which is not noticeable once placed against a wall.  Dimensions are 33.5"Hx33"W.17"D.
#
# Post ID:  7714544660
# posted: 2024-02-04 21:05
# No update yet
#
# Title: Dell SE2216H 22" LCD Monitor
# https://images.craigslist.org/00n0n_ghDhHkFfxF2_0i90db_600x450.jpg
# 22" screen.  Used, but in great condition.  Like new.  Max resolution 1920 x 1080.
#
# Post ID:  7714544897
# posted: 2024-02-04 21:08
# No update yet
#
# Title: Free wood floors
# https://images.craigslist.org/00x0x_7mvj9BkIajh_0lM0t2_600x450.jpg
# Leftover pieces from a larger project. 5 boxes, 100 sqft total
#
# This product
# https://www.homedepot.com/p/Bruce-Laurel-Gunstock-Oak-3-4-in-Thick-x-2-1-4-in-Wide-x-Varying-Length-Solid-Hardwood-Flooring-20-sqft-case-CB924/100118026
#
# Post ID:  7714545155
# posted: 2024-02-04 21:10
# No update yet
#
# Title: Free cabinet organizers
# https://images.craigslist.org/00H0H_hNzJ1P9zdh9_0lM0t2_600x450.jpg
# As pictured
#
# Post ID:  7714545164
# posted: 2024-02-04 21:11
# No update yet
#
# Title: Free garden wall cinderblocks
# https://images.craigslist.org/00i0i_j8TE7KNlFAn_0lM0t2_600x450.jpg
# about 20-30 of them. They're sitting in the ground as pictured, so bring a shovel or trowel
#
# Post ID:  7714545180
# posted: 2024-02-04 21:11
# No update yet
#
# Title: Wooden glider rocking chair with pads (free)
# https://images.craigslist.org/00b0b_eJWt7CNsJ0V_0CI0t2_600x450.jpg
# White wooden gliding chair with grey pads good for relaxing or nursing a baby.
#
# Used, but in OK condition (cosmetic) works perfectly
#
# Pickup only
#
# Post ID:  7714546001
# posted: 2024-02-04 21:18
# No update yet
#
# Title: FREE 10 Waterproof ID Badge Holders in Hard Plastic with Lanyard
# https://images.craigslist.org/01010_ieVeTFcDNPN_0CI0pt_600x450.jpg
# 10 Waterproof ID Badge Holders in Hard Plastic Card Case Slim with Lanyard
#
# If the post is up they are available.
#
# Please offer some good times for pickup.
#
# Post ID:  7714546254
# posted: 2024-02-04 21:21
# No update yet
#
# Title: Free and great condition- Cal King box springs
# https://images.craigslist.org/01212_ka2mwd5kJdi_0t20CI_600x450.jpg
# Free and in great condition CAL KING BOX SPRINGS (2 pieces)
#
# LxWxH
# 84” x 72” x 9” (combined measurements)
#
# ***Pick up only and bring a truck**
#  Text  show contact info
# Post ID:  7714546351
# posted: 2024-02-04 21:22
# updated: 2024-02-04 21:24
#
# Title: Garage cabinets (2)
# https://images.craigslist.org/00m0m_10vdYMrpdQc_0CI0t2_600x450.jpg
# Giving away two sturdy 4'x4'x1' (exterior dimensions) cabinets that came with the house.
#
# Can deliver (also free) most anywhere on the Peninsula.
#
# Post ID:  7714546515
# posted: 2024-02-04 21:23
# No update yet
#
# Title: FREE Outdoor Tiles
# https://images.craigslist.org/00n0n_eSRel07O8f9_0mr0eI_600x450.jpg
# I have about 10 pieces of 16x16 outdoor tiles unused from a previous project and I hate to dump them in the trash. The tile is thick. If you can repurpose it, send me a message.
#
# Pick up is in S. San Jose (Santa Teresa & Snell Ave)
#
# Post ID:  7714549146
# posted: 2024-02-04 21:51
# updated: 2024-02-04 22:07
#
# Title: Nightstand
# https://images.craigslist.org/00v0v_9uIeXfAmKOH_0lM0t2_600x450.jpg
# White, one drawer nightstand
# Height: 24"
# Depth (front to back):15-3/4"
# Width: 17-3/4"
#
# Post ID:  7714549199
# posted: 2024-02-04 21:51
# No update yet
#
# Title: Two drawer file cabinet
# https://images.craigslist.org/00y0y_k5TdSbUenfE_0CI0t2_600x450.jpg
# Two drawer, white melamine file cabinet
#
# Height: 29"
# Width: 37-1/2"
# Depth (front to back): 17-3/4"
#
# Post ID:  7714549739
# posted: 2024-02-04 21:58
# No update yet
#
# Title: Ankle Foot Medical CAM Boots Unisex SMALL
# https://images.craigslist.org/01010_liYHHsAhQ4F_0Cz0t2_600x450.jpg
# Hello,
#
# I have 2  ankle / foot CAM medical boots to give away (the short one is taken). I recently recovered from foot surgery and used all 3 boots sparingly. Why do I have 3? I used a tall one for outside, another tall one for inside the house, and the short one very briefly when I got better right before able to wear shoes again.
#
# 1 of the tall boots have the ability to pump air for more ankle support
#
# All are very clean and well kept. They are unisex small. I wear a size 8 women's shoes. Will work up to size 9 womens, size 7 mens.
#
# Come take them all as you get ready for ankle or foot rehab. The doctor always seems to give you the most uncomfortable ones!
#
# Post ID:  7714551359
# posted: 2024-02-04 22:17
# No update yet
#
# Title: Bolster pillow
# https://images.craigslist.org/00J0J_dLoChjicHzB_0t20CI_600x450.jpg
# Pottery Barn 10” X 27” A great decorative/accent pillow for sofa, chair, bedroom.
#
# Post ID:  7714551361
# posted: 2024-02-04 22:17
# No update yet

# %% [markdown]
# ## Part 3: Automating Login on The Old Reader

# %%
#2. Exploring the Login Mechanism
headers = {'User-agent': 'Mozilla/5.0'}
url_part3 = 'https://theoldreader.com/users/sign_in'
page_3 = requests.get(url_part3, headers = headers)
soup3 = BeautifulSoup(page_3.content, "html.parser")

print(soup3.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
#   <link href="https://fonts.googleapis.com/css?family=Montserrat:400,600" rel="stylesheet" type="text/css"/>
#   <!-- Latest compiled and minified JavaScript -->
#   <script src="https://code.jquery.com/jquery.js">
#   </script>
#   <script src="//netdna.bootstrapcdn.com/bootstrap/3.0.1/js/bootstrap.min.js">
#   </script>
#   <link href="https://fonts.googleapis.com/css?family=Source+Code+Pro" rel="stylesheet" type="text/css"/>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,800" rel="stylesheet"/>
#   <link href="//s.theoldreader.com/assets/reader/public-c7869a909c7b119a27fb646003828344.css" media="screen" rel="stylesheet" type="text/css">
#    <link href="//s.theoldreader.com/assets/apple-touch-icon-57x57-86fe1176e14af4907a6fecfe5ca7e3f1.png" rel="apple-touch-icon-precomposed" sizes="57x57">
#     <link href="//s.theoldreader.com/assets/apple-touch-icon-114x114-bae89acc41c93261dd962ea6ade08d22.png" rel="apple-touch-icon-precomposed" sizes="114x114">
#      <link href="//s.theoldreader.com/assets/apple-touch-icon-72x72-f248503edfa3676f8d58af531aff7e88.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#      <link href="//s.theoldreader.com/assets/apple-touch-icon-144x144-510415291cae9b46a9ca4ac39815104e.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#      <link href="//s.theoldreader.com/assets/apple-touch-icon-60x60-3426eab125af02dea4867aad969752b2.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#      <link href="//s.theoldreader.com/assets/apple-touch-icon-120x120-3ab011024abf6fe2cfc9a8bb4523acf2.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#      <link href="//s.theoldreader.com/assets/apple-touch-icon-76x76-98376acc9def00445bcc4f35550f5af5.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#      <link href="//s.theoldreader.com/assets/apple-touch-icon-152x152-3e21226fd0e2c9d17119cbe5d5805b42.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#      <link href="//s.theoldreader.com/assets/favicon-196x196-b2a8c74975d8498591dd629b89797dea.png" rel="icon" sizes="196x196" type="image/png"/>
#      <link href="//s.theoldreader.com/assets/favicon-96x96-6c52a26e02fc07430a98ef484a148f2f.png" rel="icon" sizes="96x96" type="image/png"/>
#      <link href="//s.theoldreader.com/assets/favicon-32x32-14f0ea359e8c8a5f19e253ff39e89505.png" rel="icon" sizes="32x32" type="image/png"/>
#      <link href="//s.theoldreader.com/assets/favicon-16x16-dbff886c76bb71ed112d1fa5d99850d2.png" rel="icon" sizes="16x16" type="image/png"/>
#      <link href="//s.theoldreader.com/assets/favicon-128-19aa7ffa16364aba074472efe4a432d5.png" rel="icon" sizes="128x128" type="image/png"/>
#      <meta content="The Old Reader" name="application-name">
#       <meta content="#FFFFFF" name="msapplication-TileColor">
#        <meta content="//s.theoldreader.com/assets/mstile-144x144-510415291cae9b46a9ca4ac39815104e.png" name="msapplication-TileImage">
#         <meta content="//s.theoldreader.com/assets/mstile-70x70-19aa7ffa16364aba074472efe4a432d5.png" name="msapplication-square70x70logo"/>
#         <meta content="//s.theoldreader.com/assets/mstile-150x150-c50a4164ebb6d3c497822664cb7cb284.png" name="msapplication-square150x150logo"/>
#         <meta content="//s.theoldreader.com/assets/mstile-310x150-1b07e17c2f6ecf4a4dc2737f0aa2060d.png" name="msapplication-wide310x150logo"/>
#         <meta content="//s.theoldreader.com/assets/mstile-310x310-4bdd40346db4dd8b402ea5642536e1e0.png" name="msapplication-square310x310logo"/>
#         <link color="#ff2400" href="//s.theoldreader.com/assets/website-icon-890cace9fbea886aaaeb94840b916e20.svg" rel="mask-icon"/>
#         <link href="//s.theoldreader.com/assets/favicon-9a70b996deb81293c0b8a361cfe24228.ico" rel="shortcut icon"/>
#         <meta content="167033558637456" property="fb:app_id"/>
#         <meta content="website" property="og:type"/>
#         <meta content="https://theoldreader.com/users/sign_in" property="og:url"/>
#         <meta content="The Old Reader | Sign In" property="og:title"/>
#         <title>
#          The Old Reader | Sign In
#         </title>
#         <meta content="https://s.theoldreader.com/assets/favicon-196x196-b2a8c74975d8498591dd629b89797dea.png" property="og:image"/>
#         <link href="https://s.theoldreader.com/assets/favicon-196x196-b2a8c74975d8498591dd629b89797dea.png" rel="image_src">
#          <meta content="Read all your favorite online content in one place. Import your subscriptions in one click, find your friends, and start sharing." property="og:description"/>
#          <meta content="Read all your favorite online content in one place. Import your subscriptions in one click, find your friends, and start sharing." name="description"/>
#          <meta content="The Old Reader" property="og:site_name"/>
#          <meta content="the old reader, rss, rss reader, rss aggregator" name="keywords"/>
#          <meta content="pk_live_aAbJCQJbM1C5PFdlUQ09yZHh" name="stripe-key"/>
#          <meta content="v60" http-equiv="x-pjax-version"/>
#          <meta content="script-src 'self' 'unsafe-inline' 'unsafe-eval' s.theoldreader.com www.google-analytics.com www.googleadservices.com fonts.googleapis.com sdk.spritzinc.com js.stripe.com platform.instagram.com platform.twitter.com syndication.twitter.com connect.facebook.net www.google.com www.gstatic.com cdn.syndication.twimg.com d2wy8f7a9ursnm.cloudfront.net cdnjs.cloudflare.com pagead2.googlesyndication.com www.instagram.com tpc.googlesyndication.com contextual.media.net partner.googleadservices.com adservice.google.com;" http-equiv="Content-Security-Policy">
#           <script data-apikey="fbe8565186cf5b4325c66071e7b0aab1" data-appversion="60" src="//d2wy8f7a9ursnm.cloudfront.net/bugsnag-3.min.js">
#           </script>
#           <script type="text/javascript">
#            if (typeof Bugsnag !== "undefined" && Bugsnag !== null) {
#     Bugsnag.releaseStage = "production";
#     Bugsnag.notifyReleaseStages = ['production'];
#   }
#           </script>
#           <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#           <!--[if lt IE 9]>
#   <script src="//html5shim.googlecode.com/svn/trunk/html5.js" type="text/javascript"></script>
# <![endif]-->
#           <meta content="authenticity_token" name="csrf-param"/>
#           <meta content="owGBoofmwMxiSQc/4isCRN3mIalZjeX8r8eVpRXjDMo=" name="csrf-token"/>
#           <script type="text/javascript">
#            (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-32299218-1', 'auto');
#   ga('send', 'pageview');
#           </script>
#           <script type="text/javascript">
#            /* <![CDATA[ */
#  goog_snippet_vars = function() {
#    var w = window;
#    w.google_conversion_id = 906647471;
#    w.google_conversion_label = "jUCNCNqw414Qr6-psAM";
#    w.google_remarketing_only = false;
#  }
#  // DO NOT CHANGE THE CODE BELOW.
#  goog_report_conversion = function(url) {
#    goog_snippet_vars();
#    window.google_conversion_format = "3";
#    window.google_is_call = true;
#    var opt = new Object();
#    opt.onload_callback = function() {
#    if (typeof(url) != 'undefined') {
#      window.location = url;
#    }
#  }
#  var conv_handler = window['google_trackConversion'];
#  if (typeof(conv_handler) == 'function') {
#    conv_handler(opt);
#  }
# }
# /* ]]> */
#           </script>
#           <script src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#           </script>
#          </meta>
#         </link>
#        </meta>
#       </meta>
#      </meta>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body>
#   <div class="container-fluid">
#    <div class="row">
#     <div class="col-md-12">
#      <div class="interior-header-background">
#       <div class="rounded_bottom">
#       </div>
#      </div>
#      <div class="row interior">
#       <div class="col-md-12">
#        <div class="devise-form-continer">
#         <h2>
#          Sign In
#         </h2>
#         <form accept-charset="UTF-8" action="/users/sign_in" class="new_user" id="new_user" method="post" role="form">
#          <div style="margin:0;padding:0;display:inline">
#           <input name="utf8" type="hidden" value="✓"/>
#           <input name="authenticity_token" type="hidden" value="owGBoofmwMxiSQc/4isCRN3mIalZjeX8r8eVpRXjDMo="/>
#          </div>
#          <div class="form-group">
#           <input autocapitalize="off" autocorrect="off" autofocus="autofocus" class="form-control" id="user_login" name="user[login]" placeholder="Username/Email" size="30" spellcheck="false" type="text"/>
#          </div>
#          <div class="form-group">
#           <input class="form-control" id="user_password" name="user[password]" placeholder="Password" size="30" type="password"/>
#          </div>
#          <input class="btn btn-primary btn-block" name="commit" type="submit" value="Sign In"/>
#         </form>
#         <div class="links">
#          <a href="/users/password/new">
#           Forgot password?
#          </a>
#          <br/>
#          <a href="/users/unlock/new">
#           Need unlock instructions?
#          </a>
#          <br/>
#         </div>
#         <hr/>
#         <div class="oauth">
#          <p>
#           <button data-target="#google-broke-modal" data-toggle="modal" id="fake-goog-btn" type="button">
#            Sign in with Google
#           </button>
#           <!-- removing facebook login, this button is the deprication notice vehicle -->
#          </p>
#         </div>
#         <div class="tos">
#          By registering or signing in, you are agreeing to our
#          <a href="/pages/tos" rel="noopener noreferrer" target="_blank">
#           Terms Of Service
#          </a>
#          and
#          <a href="/pages/privacy" rel="noopener noreferrer" target="_blank">
#           Privacy Policy
#          </a>
#         </div>
#        </div>
#        <hr/>
#       </div>
#      </div>
#      <div class="row footer">
#       <div class="col-md-12">
#        <div class="row">
#         <div class="col-md-2">
#          <a class="footer-icon hidden-sm hidden-xs" href="/home">
#          </a>
#         </div>
#         <div class="col-md-10 nav-links">
#          <p>
#           <a href="/users/sign_up">
#            Sign Up
#           </a>
#          </p>
#          <p>
#           <a href="/users/sign_in">
#            Sign In
#           </a>
#          </p>
#          <p>
#           <a href="/pages/tour">
#            Product Tour
#           </a>
#          </p>
#          <p>
#           <a href="/pages/apps">
#            Apps
#           </a>
#          </p>
#          <p>
#           <a href="/pages/contact">
#            Contact Us
#           </a>
#          </p>
#         </div>
#        </div>
#        <div class="row">
#         <div class="col-md-6">
#          <a href="https://twitter.com/theoldreader">
#           <i class="fa fa-twitter">
#           </i>
#           Twitter
#          </a>
#          <a href="https://www.facebook.com/theoldreader">
#           <i class="fa fa-facebook-square">
#           </i>
#           Facebook
#          </a>
#          <a href="http://blog.theoldreader.com">
#           <i class="fa fa-rss">
#           </i>
#           Blog
#          </a>
#         </div>
#         <div class="col-md-6 terms-text">
#          <a href="/pages/privacy">
#           Privacy policy
#          </a>
#          |
#          <a href="/pages/tos">
#           Terms of Service
#          </a>
#          © 2012-2024 The Old Reader
#         </div>
#        </div>
#       </div>
#      </div>
#      <script src="//s.theoldreader.com/assets/public-5f12d594e3f83bcc960d62452ce6c1c7.js" type="text/javascript">
#      </script>
#     </div>
#    </div>
#   </div>
#   <div class="header-scrolled show">
#    <div class="container-fluid">
#     <div class="row">
#      <div class="col-md-12">
#       <div class="header clearfix">
#        <a class="logo" href="/home">
#        </a>
#        <div class="sign-up hidden-sm hidden-xs">
#         <a href="/users/sign_up">
#          Sign Up
#         </a>
#         <div class="vertical-line">
#          <div>
#          </div>
#         </div>
#         <a href="/users/sign_in" onclick="ga('send', 'event', 'Login Header', 'click')">
#          Sign In
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8488747604526930">
#   </script>
#  </body>
#  <div aria-hidden="true" aria-labelledby="#fb-deprication-modal" class="modal fade" id="fb-deprication-modal" role="dialog" tabindex="-1">
#   <div class="modal-dialog" role="document">
#    <div class="modal-content">
#     <div class="modal-header">
#      <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#       ×
#      </button>
#     </div>
#     <div class="modal-body">
#      <p id="fb-deprication-notice">
#       Due to continued changes with Facebook login and concerns about privacy with Facebook, we've decided to stop supporting Facebook login. It's easy to transition your account by using the
#       <a href="/users/password/new">
#        Forgot password?
#       </a>
#       link and entering the email address associated with your Facebook account. Then you can set a password and login directly to The Old Reader. Thanks for your understanding and thanks for continuing to use The Old Reader.
#      </p>
#     </div>
#     <div class="modal-footer">
#      <button aria-hidden="true" class="btn btn-default" data-dismiss="modal">
#       Close
#      </button>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div aria-hidden="true" aria-labelledby="#google-broke-modal" class="modal fade" id="google-broke-modal" role="dialog" tabindex="-1">
#   <div class="modal-dialog" role="document">
#    <div class="modal-content">
#     <div class="modal-header">
#      <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#       ×
#      </button>
#     </div>
#     <div class="modal-body">
#      <p id="fb-deprication-notice">
#       Google Sign In is not currently working due to an issue with our host. It's easy to login to your account by using the
#       <a href="/users/password/new">
#        Forgot password?
#       </a>
#       link and entering the email address associated with your google account. Then you can set a password and login directly to The Old Reader. We will remove this message when the issue is resolved and you will be able to resume logging in using Google Sign In. Thanks for your understanding and thanks for continuing to use The Old Reader.
#      </p>
#     </div>
#     <div class="modal-footer">
#      <button aria-hidden="true" class="btn btn-default" data-dismiss="modal">
#       Close
#      </button>
#     </div>
#    </div>
#   </div>
#  </div>
#  <script>
#   $('#fake-fb-btn').on('click',function() {
#       $('#fb-deprication-notice').modal('show')
#     })
#     $('#fake-goog-btn').on('click',function() {
#       $('#google-broke-modal').modal('show')
#     })
#  </script>
# </html>

# %%
# Document all `<input>` fields within the login form, paying special attention to their name attributes.
# These fields are crucial for submitting the login request programmatically.

inputs = soup3.select('input')

for i in range(len(inputs)):
    print(i+1,inputs[i])

# We can see the input fields for utf8, authenticity_token, user[login], user[password], and commit
# Out:
# 1 <input name="utf8" type="hidden" value="✓"/>
# 2 <input name="authenticity_token" type="hidden" value="owGBoofmwMxiSQc/4isCRN3mIalZjeX8r8eVpRXjDMo="/>
# 3 <input autocapitalize="off" autocorrect="off" autofocus="autofocus" class="form-control" id="user_login" name="user[login]" placeholder="Username/Email" size="30" spellcheck="false" type="text"/>
# 4 <input class="form-control" id="user_password" name="user[password]" placeholder="Password" size="30" type="password"/>
# 5 <input class="btn btn-primary btn-block" name="commit" type="submit" value="Sign In"/>

# %% [markdown]
# 3. Analyzing Network Traffic for Login Request
#  - The network request I made during login is a POST request. This is because that I am sending my login information such as username and password to the web server.
#
#  - After manually logging in the website, I noticed that there are 5 variables passed, which are:
#      - utf8
#      - authenticity_token
#      - user[login]
#      - user[password]
#      - commit
#
#  - These variables are also the same as the names of the input elements under form. Therefore, when I intend to make the POST request here, I also need to submit all these variables with values.

# %%
# find the inputs beside username and password
input1 = soup3.select_one('input[name=utf8]')
utf8 = input1.get('value')

input2 = soup3.select_one('input[name=authenticity_token]')
auth_token = input2.get('value')

input3 = soup3.select_one('input[name=commit]')
commit = input3.get('value')

print(utf8)
print(auth_token)
print(commit)
# Out:
# ✓
# owGBoofmwMxiSQc/4isCRN3mIalZjeX8r8eVpRXjDMo=
# Sign In

# %%
# 4. Automating the Login Process
time.sleep(5) # add delay of 5 seconds

# An open session carries the cookies and allows you to make post requests
session = requests.session()

# Send POST request with all 5 variables to the login form’s action URL to log in
res = session.post(url_part3, 
                        data = {'utf8': utf8,
                                'authenticity_token': auth_token,
                                'user[login]': 'leoliao@ucdavis.edu',
                                'user[password]': 'Password123',
                                'commit': commit
                               },
                        timeout = 20)

# get cookies and inspect
cookies = session.cookies.get_dict()
print(cookies)
# Out:
# {'_new_reader_session': 'BAh7CkkiD3Nlc3Npb25faWQGOgZFVEkiJWM3ZjI3MjVhYjdiZmYzNjMzODQyMjU4N2VhYzRhOTY5BjsAVEkiGXdhcmRlbi51c2VyLnVzZXIua2V5BjsAVFsHWwZVOhpNb3BlZDo6QlNPTjo6T2JqZWN0SWQiES64DJ%2B4Po9VrZBChkkiIiQyYSQwNSRyL3FZWTVhbi9SSmNpTnhzSWJoM2hPBjsAVEkiDWxhbmd1YWdlBjsARjoHZW5JIhByZWRpcmVjdF90bwY7AEZJIgYvBjsARkkiEF9jc3JmX3Rva2VuBjsARkkiMVl0dHR6UGpPZG5rbDROQldKZHJaV1RCbm9CRDh2UzFBU1pQLzVYV3M3YVk9BjsARg%3D%3D--bd91cecded92607844340bd32d79fa93e6507636', 'i_know_you': 'Leo', 'remember_user_token': 'BAhbB1sGVToaTW9wZWQ6OkJTT046Ok9iamVjdElkIhEuuAyfuD6PVa2QQoZJIiIkMmEkMDUkci9xWVk1YW4vUkpjaU54c0liaDNoTwY6BkVU--45e49958d371e56b1da04c43e04a0f49f4c7c680', 'signed_at': '1707346427'}

# %%
# 5. Verifying Successful Login
time.sleep(5) # add delay of 5 seconds

# Use cookies to log into the user edit page, which is only available when logged in.
page4 = requests.get('https://theoldreader.com/users/edit', cookies=cookies)
soup4 = BeautifulSoup(page4.content, "html.parser")

print(soup4.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
#   <link href="//s.theoldreader.com/assets/application-befb06d5a14978388154b51422cef437.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-57x57-86fe1176e14af4907a6fecfe5ca7e3f1.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-114x114-bae89acc41c93261dd962ea6ade08d22.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-72x72-f248503edfa3676f8d58af531aff7e88.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-144x144-510415291cae9b46a9ca4ac39815104e.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-60x60-3426eab125af02dea4867aad969752b2.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-120x120-3ab011024abf6fe2cfc9a8bb4523acf2.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-76x76-98376acc9def00445bcc4f35550f5af5.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-152x152-3e21226fd0e2c9d17119cbe5d5805b42.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#   <link href="//s.theoldreader.com/assets/favicon-196x196-b2a8c74975d8498591dd629b89797dea.png" rel="icon" sizes="196x196" type="image/png"/>
#   <link href="//s.theoldreader.com/assets/favicon-96x96-6c52a26e02fc07430a98ef484a148f2f.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="//s.theoldreader.com/assets/favicon-32x32-14f0ea359e8c8a5f19e253ff39e89505.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="//s.theoldreader.com/assets/favicon-16x16-dbff886c76bb71ed112d1fa5d99850d2.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="//s.theoldreader.com/assets/favicon-128-19aa7ffa16364aba074472efe4a432d5.png" rel="icon" sizes="128x128" type="image/png"/>
#   <meta content="The Old Reader" name="application-name">
#    <meta content="#FFFFFF" name="msapplication-TileColor">
#     <meta content="//s.theoldreader.com/assets/mstile-144x144-510415291cae9b46a9ca4ac39815104e.png" name="msapplication-TileImage">
#      <meta content="//s.theoldreader.com/assets/mstile-70x70-19aa7ffa16364aba074472efe4a432d5.png" name="msapplication-square70x70logo"/>
#      <meta content="//s.theoldreader.com/assets/mstile-150x150-c50a4164ebb6d3c497822664cb7cb284.png" name="msapplication-square150x150logo"/>
#      <meta content="//s.theoldreader.com/assets/mstile-310x150-1b07e17c2f6ecf4a4dc2737f0aa2060d.png" name="msapplication-wide310x150logo"/>
#      <meta content="//s.theoldreader.com/assets/mstile-310x310-4bdd40346db4dd8b402ea5642536e1e0.png" name="msapplication-square310x310logo"/>
#      <link color="#ff2400" href="//s.theoldreader.com/assets/website-icon-890cace9fbea886aaaeb94840b916e20.svg" rel="mask-icon"/>
#      <link href="//s.theoldreader.com/assets/favicon-9a70b996deb81293c0b8a361cfe24228.ico" rel="shortcut icon"/>
#      <meta content="167033558637456" property="fb:app_id"/>
#      <meta content="website" property="og:type"/>
#      <meta content="https://theoldreader.com/users/edit" property="og:url"/>
#      <meta content="The Old Reader" property="og:title"/>
#      <meta content="https://s.theoldreader.com/assets/favicon-196x196-b2a8c74975d8498591dd629b89797dea.png" property="og:image"/>
#      <link href="https://s.theoldreader.com/assets/favicon-196x196-b2a8c74975d8498591dd629b89797dea.png" rel="image_src">
#       <meta content="Read all your favorite online content in one place. Import your subscriptions in one click, find your friends, and start sharing." property="og:description"/>
#       <meta content="Read all your favorite online content in one place. Import your subscriptions in one click, find your friends, and start sharing." name="description"/>
#       <meta content="The Old Reader" property="og:site_name"/>
#       <meta content="the old reader, rss, rss reader, rss aggregator" name="keywords"/>
#       <meta content="pk_live_aAbJCQJbM1C5PFdlUQ09yZHh" name="stripe-key"/>
#       <meta content="v60" http-equiv="x-pjax-version"/>
#       <meta content="script-src 'self' 'unsafe-inline' 'unsafe-eval' s.theoldreader.com www.google-analytics.com www.googleadservices.com fonts.googleapis.com sdk.spritzinc.com js.stripe.com platform.instagram.com platform.twitter.com syndication.twitter.com connect.facebook.net www.google.com www.gstatic.com cdn.syndication.twimg.com d2wy8f7a9ursnm.cloudfront.net cdnjs.cloudflare.com pagead2.googlesyndication.com www.instagram.com tpc.googlesyndication.com contextual.media.net partner.googleadservices.com adservice.google.com;" http-equiv="Content-Security-Policy">
#        <script data-apikey="fbe8565186cf5b4325c66071e7b0aab1" data-appversion="60" src="//d2wy8f7a9ursnm.cloudfront.net/bugsnag-3.min.js">
#        </script>
#        <script type="text/javascript">
#         if (typeof Bugsnag !== "undefined" && Bugsnag !== null) {
#     Bugsnag.releaseStage = "production";
#     Bugsnag.notifyReleaseStages = ['production'];
#     Bugsnag.user = {
#       id: "2eb80c9fb83e8f55ad904286",
#       name: "Leo",
#       email: "leoliao@ucdavis.edu"
#     }
#   }
#        </script>
#        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#        <!--[if lt IE 9]>
#   <script src="//html5shim.googlecode.com/svn/trunk/html5.js" type="text/javascript"></script>
# <![endif]-->
#        <meta content="authenticity_token" name="csrf-param"/>
#        <meta content="32+pRl9xW0lqApXNZ2UwGLwriqcFO8Ok3471Zv+TbZk=" name="csrf-token"/>
#        <script type="text/javascript">
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-32299218-1', 'auto');
#   ga('send', 'pageview');
#        </script>
#        <script type="text/javascript">
#         /* <![CDATA[ */
#  goog_snippet_vars = function() {
#    var w = window;
#    w.google_conversion_id = 906647471;
#    w.google_conversion_label = "jUCNCNqw414Qr6-psAM";
#    w.google_remarketing_only = false;
#  }
#  // DO NOT CHANGE THE CODE BELOW.
#  goog_report_conversion = function(url) {
#    goog_snippet_vars();
#    window.google_conversion_format = "3";
#    window.google_is_call = true;
#    var opt = new Object();
#    opt.onload_callback = function() {
#    if (typeof(url) != 'undefined') {
#      window.location = url;
#    }
#  }
#  var conv_handler = window['google_trackConversion'];
#  if (typeof(conv_handler) == 'function') {
#    conv_handler(opt);
#  }
# }
# /* ]]> */
#        </script>
#        <script src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#        </script>
#        <title data-bind="text: title">
#         The Old Reader
#        </title>
#        <script type="text/javascript">
#         var FEEDS = {
#     feeds: [{"position":null,"id":null,"subscriptions":[],"title":null,"destroyed":null},{"position":1,"id":"65c2a260c70bc2b515000181","subscriptions":[{"feed_id":"aed846f0d597789927a7ce68","folder_id":"65c2a260c70bc2b515000181","position":1,"id":"65c2a261c70bc2b515000185","icon":"/system/uploads/feed/picture/aed8/46f0/d597/7899/27a7/icon_ce68.ico","url":"https://www.apartmenttherapy.com/main.rss","share_count":null,"star_count":null,"comment_count":null,"sendto_count":null,"title_click_count":null,"body_link_click_count":null,"mark_all_as_read_count":null,"likes_count":null,"title":"Apartment Therapy| Saving the world, one room at a time","unread_count":10,"destroyed":null},{"feed_id":"ded4c2c4abc703638c0a2a79","folder_id":"65c2a260c70bc2b515000181","position":2,"id":"65c2a269c70bc2b515000193","icon":"/system/uploads/feed/picture/ded4/c2c4/abc7/0363/8c0a/icon_2a79.ico","url":"https://www.getrichslowly.org/feed/","share_count":null,"star_count":null,"comment_count":null,"sendto_count":null,"title_click_count":null,"body_link_click_count":null,"mark_all_as_read_count":null,"likes_count":null,"title":"Get Rich Slowly","unread_count":10,"destroyed":null},{"feed_id":"514d5f3d54cf82eed0004675","folder_id":"65c2a260c70bc2b515000181","position":3,"id":"65c2a26dc70bc2b5150001a1","icon":"/system/uploads/feed/picture/514d/5f3d/54cf/82ee/d000/icon_4675.ico","url":"https://what-if.xkcd.com/feed.atom","share_count":null,"star_count":null,"comment_count":null,"sendto_count":null,"title_click_count":null,"body_link_click_count":null,"mark_all_as_read_count":null,"likes_count":null,"title":"what if?","unread_count":5,"destroyed":null},{"feed_id":"50e2ea09bd927918880000a7","folder_id":"65c2a260c70bc2b515000181","position":4,"id":"65c2a273c70bc2b5150001aa","icon":"/system/uploads/feed/picture/50e2/ea09/bd92/7918/8800/icon_00a7.ico","url":"http://blog.theoldreader.com/rss","share_count":null,"star_count":null,"comment_count":null,"sendto_count":null,"title_click_count":null,"body_link_click_count":null,"mark_all_as_read_count":null,"likes_count":null,"title":"The Old Reader: behind the scenes","unread_count":10,"destroyed":null},{"feed_id":"514e224954cf822997011be6","folder_id":"65c2a260c70bc2b515000181","position":5,"id":"65c2a279c70bc2b5150001b8","icon":"/system/uploads/feed/picture/514e/2249/54cf/8229/9701/icon_1be6.ico","url":"https://thedailywhat.cheezburger.com/rss","share_count":null,"star_count":null,"comment_count":null,"sendto_count":null,"title_click_count":null,"body_link_click_count":null,"mark_all_as_read_count":null,"likes_count":null,"title":"The Daily What","unread_count":10,"destroyed":null}],"title":"The Old Reader Picks","destroyed":null}],
#     following: [],
#     comments: 0,
#     new_suggested: false
#   };
#   var SETTINGS = {"destroyed":false,"show_all":true,"show_list":false,"show_reverse":false,"notify_followed":true,"click_to_scroll":false,"scroll_to_read":"full","sidebar_unread_only":false,"sidebar_alpha":false,"share_timeline":false,"show_fb_profile":true,"locale":"en","use_spritz":false,"dont_email_news_updates":false,"dont_email_recs":false,"dismissed_paid_message":true,"confirm_read_all":false,"private_mode":false,"dark_theme":false,"font_size":13};
#   var SENDTOS = [{"_id":"65c2ab7bc70bc22ec4000019","is_enabled":true,"provider":"mailto","title":"Email","url":"mailto:?subject=%{title}\u0026body=%{url}%0D%0A%0D%0A%28via%20theoldreader.com%29"},{"_id":"65c2ab7bc70bc22ec400001a","is_enabled":true,"provider":"facebook","title":"Facebook","url":"https://www.facebook.com/dialog/share?app_id=167033558637456\u0026display=popup\u0026redirect_uri=http%3A%2F%2Ftheoldreader.com%2Ffacebook_callback.html\u0026href=%{url}"},{"_id":"65c2ab7bc70bc22ec400001b","is_enabled":true,"provider":"twitter","title":"Twitter","url":"https://twitter.com/intent/tweet?url=%{url}\u0026text=%{title}\u0026via=theoldreader"}]
#   var USERINFO = {"id":"2eb80c9fb83e8f55ad904286","display_name":"Leo","icon_url":"//s.theoldreader.com/icons/user_icon.png","profile_url":"https://theoldreader.com/posts/profile/2eb80c9fb83e8f55ad904286"}
#        </script>
#        <script type="text/javascript">
#         window._mNHandle = window._mNHandle || {};
#     window._mNHandle.queue = window._mNHandle.queue || [];
#     medianet_versionId = "3121199";
#        </script>
#        <script async="async" src="https://contextual.media.net/dmedianet.js?cid=8CUB6WHOQ">
#        </script>
#       </meta>
#      </link>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="theme-status reader fixed-header" data-behavior="reader" data-dark-theme="false">
#   <!-- find me in shared/header -->
#   <nav class="navbar navbar-default navbar-fixed-top">
#    <div class="container-fluid">
#     <div class="row">
#      <div class="col-md-3">
#       <!-- Brand and toggle get grouped for better mobile display -->
#       <div class="navbar-header">
#        <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar-collapse" data-toggle="collapse" type="button">
#         <span class="sr-only">
#          Toggle navigation
#         </span>
#         <span class="icon-bar">
#         </span>
#         <span class="icon-bar">
#         </span>
#         <span class="icon-bar">
#         </span>
#        </button>
#        <a class="brand" data-pjax="" href="/">
#        </a>
#       </div>
#      </div>
#      <div class="col-md-9">
#       <!-- Collect the nav links, forms, and other content for toggling -->
#       <div class="collapse navbar-collapse" id="navbar-collapse">
#        <form action="/posts/search/%query%" class="navbar-form form-search navbar-left hidden-sm hidden-xs" role="search">
#         <div class="form-group">
#          <input class="form-control search-query" id="search-box" placeholder="Search" title="Search Terms" type="text" value=""/>
#         </div>
#         <button class="btn" type="submit">
#         </button>
#        </form>
#        <ul class="nav navbar-nav navbar-right">
#         <li class="visible-lg-inline">
#          <a class="buy-now" href="https://theoldreader.com/accounts/manage" title="More of a great thing with The Old Reader Premium">
#           Upgrade To Premium
#           <i class="fa fa-rocket">
#           </i>
#          </a>
#         </li>
#         <li class="hidden-lg">
#          <a class="buy-now" href="https://theoldreader.com/accounts/manage" title="More of a great thing with The Old Reader Premium">
#           Upgrade
#           <i class="fa fa-rocket">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="social" data-pjax="" href="/profile/friends">
#           Find Friends
#          </a>
#         </li>
#         <li>
#          <a data-pjax="" href="/feeds/import">
#           Import
#          </a>
#         </li>
#         <li class="hidden-xs">
#          <a href="mailto:support@theoldreader.com" title="Need Help?">
#           <i class="fa fa-lg fa-question-circle">
#           </i>
#          </a>
#         </li>
#         <li class="hidden-md hidden-lg">
#          <a data-pjax="" href="/posts/search">
#           Search
#          </a>
#         </li>
#         <li class="dropdown">
#          <a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="#" title="Leo">
#           Leo
#           <i class="fa fa-caret-down">
#           </i>
#          </a>
#          <ul class="dropdown-menu">
#           <li class="dropdown-header">
#            Settings
#           </li>
#           <li>
#            <a data-pjax="" href="/users/edit">
#             Manage Settings
#            </a>
#           </li>
#           <li>
#            <a href="https://theoldreader.com/accounts/manage">
#             Manage Account
#            </a>
#           </li>
#           <li>
#            <a data-pjax="" href="/subscriptions">
#             Manage Subscriptions
#            </a>
#           </li>
#           <li>
#            <a data-pjax="" href="/profile/2eb80c9fb83e8f55ad904286">
#             View Profile
#            </a>
#           </li>
#           <li class="divider">
#           </li>
#           <li class="dropdown-header">
#            Help
#           </li>
#           <li>
#            <a data-pjax="" href="/pages/tour">
#             Product Tour
#            </a>
#           </li>
#           <li>
#            <a href="mailto:support@theoldreader.com">
#             Support
#            </a>
#           </li>
#           <li class="divider">
#           </li>
#           <li>
#            <a href="/users/sign_out">
#             Sign Out
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#   </nav>
#   <div class="main-container">
#    <div class="main-row">
#     <div class="cell sidenav-cell">
#      <div class="subscribe-button-container">
#       <div class="bg">
#       </div>
#       <div class="subscribe" id="subscribe">
#        <a class="btn btn-primary btn-lg dropdown-toggle" href="#subscribe">
#         <span class="add-icon hidden-sm hidden-xs">
#         </span>
#         Add a subscription
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <form accept-charset="UTF-8" action="/feeds" class="form-inline" method="post">
#           <div style="margin:0;padding:0;display:inline">
#            <input name="utf8" type="hidden" value="✓">
#             <input name="authenticity_token" type="hidden" value="32+pRl9xW0lqApXNZ2UwGLwriqcFO8Ok3471Zv+TbZk="/>
#            </input>
#           </div>
#           <div class="control-group">
#            <table>
#             <tr>
#              <td>
#               <input class="col-md-2" id="new-feed-url" name="feed[url]" placeholder="Keyword or Feed URL" type="text"/>
#              </td>
#              <td style="width: 60px;">
#               <button class="btn btn-default" type="submit">
#                <img alt="Ico-plus" src="//s.theoldreader.com/assets/ico-plus-369f50fa00968793b3c2e814f3e55de5.png"/>
#                <i class="fa fa-spinner fa-spin" style="display:none;">
#                </i>
#               </button>
#              </td>
#             </tr>
#            </table>
#            <div class="help-block">
#            </div>
#           </div>
#          </form>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="nano banner_user" id="sidebar">
#       <div class="slide">
#        <div class="well sidebar-nav">
#         <ul class="nav sidebar-nav-list nav-list">
#          <li class="" data-bind="css: { active: '/' == Reader.View().path() }" id="sidebar-home">
#           <a data-pjax="" data-shortcut="g-h" href="/" title="Home">
#            <i class="fa fa-home">
#            </i>
#            Home
#           </a>
#          </li>
#          <li class="" data-bind="css: { active: '/posts/all' == Reader.View().path() }" id="unread_count">
#           <a data-pjax="" data-shortcut="g-a" href="/posts/all" title="All items">
#            <i class="fa fa-list">
#            </i>
#            All items
#            <span class="hidden badge badge-info" data-bind="text: unread_count, css: { hidden: unread_count() == 0 }">
#            </span>
#           </a>
#          </li>
#          <li class="" data-bind="css: { active: '/posts/starred' == Reader.View().path() }" id="sidebar-starred">
#           <a data-pjax="" data-shortcut="g-f" href="/posts/starred" title="Starred">
#            <i class="fa fa-star">
#            </i>
#            Starred
#           </a>
#          </li>
#          <li class="social" data-bind="css: { active: '/posts/liked' == Reader.View().path() }" id="sidebar-liked">
#           <a data-pjax="" data-shortcut="g-l" href="/posts/liked" title="Liked">
#            <i class="fa fa-heart">
#            </i>
#            Liked
#           </a>
#          </li>
#          <li class="social" data-bind="css: { active: '/profile/2eb80c9fb83e8f55ad904286' == Reader.View().path() }" id="sidebar-shared">
#           <a data-pjax="" data-shortcut="g-s" href="/profile/2eb80c9fb83e8f55ad904286" title="Shared">
#            <i class="fa fa-share">
#            </i>
#            Shared
#           </a>
#          </li>
#          <li class="social" data-bind="css: { active: '/bookmarks' == Reader.View().path() }" id="sidebar-bookmarked">
#           <a data-pjax="" data-shortcut="g-b" href="/bookmarks" title="Bookmarked">
#            <i class="fa fa-bookmark">
#            </i>
#            Bookmarked
#           </a>
#          </li>
#          <li class="social" data-bind="css: { active: '/posts/trending' == Reader.View().path() }" id="sidebar-trending">
#           <a data-pjax="" data-shortcut="g-t" href="/posts/trending" title="Trending">
#            <i class="fa fa-signal">
#            </i>
#            Trending
#           </a>
#          </li>
#          <li class="social hidden" data-bind="css: { active: '/posts/commented' == Reader.View().path(), hidden: comments_count() == 0 }" id="comments_count">
#           <a data-pjax="" data-shortcut="g-c" href="/posts/commented" title="Commented">
#            <i class="fa fa-comment">
#            </i>
#            Commented
#            <span class="hidden badge badge-info" data-bind="text: comments_count, css: { hidden: comments_count() == 0 }">
#            </span>
#           </a>
#          </li>
#         </ul>
#         <div class="hidden" data-bind="css: { hidden: following().length == 0, hidden_: following_unread_count() == 0 }" id="sidebar-following">
#          <ul class="nav nav-list">
#           <li class="nav-header dropdown" data-bind="css: { active: '/posts/following' == Reader.View().path() }" data-nav-item="">
#            <a class="fa" data-bind="css: { 'fa-chevron-down': !$.cookie('following_hidden'), 'fa-chevron-right': $.cookie('following_hidden') }" data-nav-collapse="" for="following" href="#">
#            </a>
#            <a data-pjax="" data-shortcut="g-p" href="/posts/following" id="following_title" title="Following">
#             <span>
#              Following
#             </span>
#             <span class="badge" data-bind="text: following_unread_count, css: { hidden: following_unread_count() == 0 }">
#             </span>
#            </a>
#           </li>
#          </ul>
#          <ul class="nav nav-list following-list" data-bind="foreach: following, sortableList: { sortList: null, container: 'following-list' }, css: { collapsed: $.cookie('following_hidden') }" id="following">
#           <li class="sort-item social" data-bind="sortableItem: { item: $data, parentList: null }, attr: { id: dom_id }, css: { active: link == Reader.View().path(), hidden_: unread_count() == 0 }" data-nav-item="">
#            <a data-bind="attr: { href: link, title: title }" data-pjax="">
#             <i class="favicon" data-bind="style: { backgroundImage: 'url(' + icon() + ')' }">
#             </i>
#             <strong data-bind="text: title">
#             </strong>
#             <span class="badge badge-info" data-bind="text: unread_count, css: { hidden: unread_count() == 0 }">
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="hidden folders-list" data-bind="foreach: folders, sortableList: { sortList: null, container: 'folders-list' }, css: { hidden: feeds_count() == 0 }">
#          <div class="sort-item" data-bind="sortableItem: { item: $data, parentList: null }, css: { prevent: id == null }">
#           <ul class="nav nav-list" data-bind="css: { hidden: (id == null &amp;&amp; feeds().length == 0) || (SETTINGS.sidebar_unread_only == true &amp;&amp; unread_count() == 0 &amp;&amp; !contains_feed(Reader.View().feed_id) &amp;&amp; link != Reader.View().path()) }">
#            <li class="nav-header dropdown" data-bind="attr: { id: dom_id + '_title' }, css: { editing: editing, active: link == Reader.View().path() }" data-nav-item="">
#             <a class="fa" data-bind="attr: { for: dom_id }, css: { 'fa-chevron-down': !hidden, 'fa-chevron-right': hidden }" data-nav-collapse="" href="#">
#             </a>
#             <a data-bind="attr: { href: link, title: title }, event: { click: click }" data-pjax="">
#              <span data-bind="text: title">
#              </span>
#              <span class="badge" data-bind="text: unread_count, css: { hidden: unread_count() == 0 }">
#              </span>
#             </a>
#             <input class="form-control" data-bind="attr: { value: title }, event: { blur: stop, keyup: keyup }" type="text"/>
#            </li>
#           </ul>
#           <ul class="nav nav-list feeds-list" data-bind="foreach: feeds, sortableList: { sortList: id, showOnStart: '.new-folder', container: 'feeds-list' }, attr: { id: dom_id }, css: { hidden: (id == null &amp;&amp; feeds().length == 0) || (SETTINGS.sidebar_unread_only == true &amp;&amp; unread_count() == 0 &amp;&amp; !contains_feed(Reader.View().feed_id) &amp;&amp; link != Reader.View().path()), collapsed: hidden } ">
#            <li class="sort-item" data-bind="sortableItem: { item: $data, parentList: folder_id }, attr: { id: dom_id }, css: { active: link == Reader.View().path(), editing: editing, hidden: SETTINGS.sidebar_unread_only == true &amp;&amp; unread_count() == 0 &amp;&amp; link != Reader.View().path() }" data-nav-item="">
#             <a data-bind="attr: { href: link, title: title }, event: { click: click } " data-pjax="">
#              <i class="favicon" data-bind="style: { backgroundImage: 'url(' + icon() + ')' }">
#              </i>
#              <strong data-bind="text: title">
#              </strong>
#              <span class="badge badge-info" data-bind="text: unread_count, css: { hidden: unread_count() == 0 }">
#              </span>
#             </a>
#             <input class="form-control" data-bind="attr: { value: title }, event: { blur: stop, keyup: keyup }" type="text"/>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <ul class="hidden nav nav-list new-folder">
#          <li class="nav-header dropdown">
#           <i class="fa fa-chevron-down">
#           </i>
#           <span>
#            New folder
#           </span>
#          </li>
#         </ul>
#         <ul class="hidden nav nav-list feeds-list new-folder sortable-clear" data-bind="sortableList: { sortList: -1, container: 'feeds-list' }">
#          <li class="prevent">
#           <em>
#            Drop here to add a new folder
#           </em>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <div class="banner" id="banner_container" style="height: 275px;">
#       <div class="banner-inner" style="padding:0;">
#        <div class="ad-wrap-tor" id="tor-ad-wrapper">
#         <a class="close" href="#" id="close_banner">
#          <i class="fa fa-times">
#          </i>
#         </a>
#         <div id="ad-container">
#          <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8488747604526930">
#          </script>
#          <!-- Fixed size Ad -->
#          <ins class="adsbygoogle" data-ad-client="ca-pub-8488747604526930" data-ad-slot="7598282246" style="display:inline-block;width:199px;height:275px">
#          </ins>
#          <script>
#           (adsbygoogle = window.adsbygoogle || []).push({});
#          </script>
#         </div>
#         <div class="hide-ad-tor" id="premium-ad-container">
#          <div class="premium-ad-inner">
#           <!-- <a href="#" class="close" id="close_prem_banner"><i class="fa fa-times"></i></a> -->
#           <h3 class="premium-ad-heading">
#            Don't like ads?
#           </h3>
#           <p class="premium-ad-text">
#            We don't either. With The Old Reader Premium, you'll never see an ad again.
#           </p>
#           <a class="premium-ad-btn" data-method="post" href="/accounts/start_trial?from_feed=true" rel="nofollow">
#            START FREE TRIAL
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="cell content-cell body-fixed-top">
#      <div class="nano" data-behavior="contents">
#       <div class="loader">
#       </div>
#       <div class="slide">
#        <div class="page-header">
#         <h1>
#          Settings
#         </h1>
#        </div>
#        <ul class="nav nav-tabs">
#         <li class="active">
#          <a data-pjax="" href="/users/edit/main">
#           Main
#          </a>
#         </li>
#         <li>
#          <a data-pjax="" href="/users/edit/social">
#           Social
#          </a>
#         </li>
#         <li>
#          <a data-pjax="" href="/users/edit/readlater">
#           Read Later
#          </a>
#         </li>
#        </ul>
#        <div class="settings-content">
#         <form accept-charset="UTF-8" action="/users" class="form-horizontal user-edit" id="edit_user" method="post">
#          <div style="margin:0;padding:0;display:inline">
#           <input name="utf8" type="hidden" value="✓"/>
#           <input name="_method" type="hidden" value="put"/>
#           <input name="authenticity_token" type="hidden" value="32+pRl9xW0lqApXNZ2UwGLwriqcFO8Ok3471Zv+TbZk="/>
#          </div>
#          <fieldset>
#           <div class="row">
#            <div class="col-md-8">
#             <div class="page-header">
#              <h2>
#               General
#              </h2>
#             </div>
#             <div class="form-group">
#              <label class="col-md-4 control-label" for="user_name">
#               Name
#              </label>
#              <div class="col-md-8">
#               <input class="form-control" id="user_name" name="user[name]" size="30" type="text" value="Leo"/>
#              </div>
#             </div>
#             <div class="form-group">
#              <label class="col-md-4 control-label" for="user_email">
#               Email
#              </label>
#              <div class="col-md-8">
#               <input class="form-control" id="user_email" name="user[email]" size="30" type="email" value="leoliao@ucdavis.edu"/>
#              </div>
#             </div>
#             <div class="form-group">
#              <label class="col-md-4 control-label" for="user_username">
#               Username
#              </label>
#              <div class="col-md-8">
#               <input class="form-control" id="user_username" name="user[username]" size="30" type="text"/>
#              </div>
#             </div>
#             <div class="form-group">
#              <label class="col-md-4 control-label" for="user_password">
#               Password
#              </label>
#              <div class="col-md-8">
#               <a class="btn btn-default" href="#" onclick="$(this).addClass('hidden').next().removeClass('hidden'); return false">
#                Change
#               </a>
#               <div class="hidden">
#                <input class="form-control" id="user_password" name="user[password]" size="30" type="password"/>
#                <span class="help-block">
#                 Your password will not be changed until you press the 'Save changes' button
#                </span>
#               </div>
#              </div>
#             </div>
#             <div class="form-group">
#              <div class="col-md-8 col-md-offset-4">
#               <div class="checkbox">
#                <label>
#                 <input name="user[dont_email_news_updates]" type="hidden" value="0"/>
#                 <input id="user_dont_email_news_updates" name="user[dont_email_news_updates]" type="checkbox" value="1"/>
#                 Please don't email me news and updates.
#                </label>
#               </div>
#               <div class="checkbox">
#                <label>
#                 <input name="user[dont_email_recs]" type="hidden" value="0"/>
#                 <input id="user_dont_email_recs" name="user[dont_email_recs]" type="checkbox" value="1"/>
#                 Please don't email me feed or post recommendations.
#                </label>
#               </div>
#               <div class="checkbox">
#                <label>
#                 <input name="user[use_ssl]" type="hidden" value="0"/>
#                 <input checked="checked" id="user_use_ssl" name="user[use_ssl]" type="checkbox" value="1"/>
#                 Use a secure
#                 <a href="http://en.wikipedia.org/wiki/HTTP_Secure" rel="noopener noreferrer" target="_blank">
#                  HTTPS
#                 </a>
#                 connection
#                </label>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="col-md-4 logins">
#             <h4>
#              You can log in to this The Old Reader account using:
#             </h4>
#             <ul>
#              <li>
#               'leoliao@ucdavis.edu' and your password (use this in any of the
#               <a data-pjax="" href="/pages/apps">
#                mobile apps
#               </a>
#               for The Old Reader)
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="row">
#            <div class="col-md-8">
#             <div class="page-header">
#              <h3>
#               User interface
#              </h3>
#             </div>
#             <div class="form-group">
#              <label class="col-md-4 control-label" for="user_locale">
#               Language
#              </label>
#              <div class="col-md-8">
#               <select class="form-control" id="user_locale" name="user[locale]">
#                <option selected="selected" value="en">
#                 English
#                </option>
#                <option value="ru">
#                 Русский
#                </option>
#                <option value="ru-old">
#                 Русскій (дореформенный)
#                </option>
#                <option value="uk">
#                 Українська
#                </option>
#                <option value="pt">
#                 Português
#                </option>
#                <option value="es">
#                 Español
#                </option>
#                <option value="fr">
#                 Français
#                </option>
#                <option value="ca">
#                 Catalan
#                </option>
#                <option value="hu">
#                 Magyar
#                </option>
#                <option value="it">
#                 Italiano
#                </option>
#                <option value="zh-CN">
#                 简体字
#                </option>
#                <option value="zh-TW">
#                 正體中文
#                </option>
#                <option value="zh-HK">
#                 粵語
#                </option>
#                <option value="de">
#                 Deutsch
#                </option>
#                <option value="sv">
#                 Svenska
#                </option>
#                <option value="tr">
#                 Türkçe
#                </option>
#                <option value="sk">
#                 Slovenčina
#                </option>
#                <option value="pl">
#                 Polski
#                </option>
#                <option value="cs">
#                 Čeština
#                </option>
#                <option value="nb">
#                 Norsk (bokmål)
#                </option>
#                <option value="el">
#                 Ελληνικά
#                </option>
#                <option value="nl">
#                 Nederlands
#                </option>
#               </select>
#              </div>
#             </div>
#             <div class="form-group">
#              <label class="col-md-4 control-label" for="user_show_all">
#               Feed display mode
#              </label>
#              <div class="col-md-8">
#               <div class="radio">
#                <label>
#                 <input checked="checked" id="user_show_all_true" name="user[show_all]" type="radio" value="true"/>
#                 Show all posts
#                </label>
#               </div>
#               <div class="radio">
#                <label>
#                 <input id="user_show_all_false" name="user[show_all]" type="radio" value="false"/>
#                 Show unread only
#                </label>
#               </div>
#              </div>
#             </div>
#             <div class="form-group">
#              <label class="col-md-4 control-label" for="user_show_list">
#               Posts view mode
#              </label>
#              <div class="col-md-8">
#               <div class="radio">
#                <label>
#                 <input id="user_show_list_true" name="user[show_list]" type="radio" value="true"/>
#                 List view
#                </label>
#               </div>
#               <div class="radio">
#                <label>
#                 <input checked="checked" id="user_show_list_false" name="user[show_list]" type="radio" value="false"/>
#                 Full view
#                </label>
#               </div>
#              </div>
#             </div>
#             <div class="form-group">
#              <label class="col-md-4 control-label" for="user_show_reverse">
#               Posts order
#              </label>
#              <div class="col-md-8">
#               <div class="radio">
#                <label>
#                 <input checked="checked" id="user_show_reverse_false" name="user[show_reverse]" type="radio" value="false"/>
#                 Normal (new posts first)
#                </label>
#               </div>
#               <div class="radio">
#                <label>
#                 <input id="user_show_reverse_true" name="user[show_reverse]" type="radio" value="true"/>
#                 Reverse (old posts first)
#                </label>
#               </div>
#              </div>
#             </div>
#             <div class="form-group">
#              <label class="col-md-4 control-label" for="user_scroll_to_read">
#               Scrolling through posts
#              </label>
#              <div class="col-md-8">
#               <select class="form-control" id="user_scroll_to_read" name="user[scroll_to_read]">
#                <option value="never">
#                 Never marks as read
#                </option>
#                <option selected="selected" value="full">
#                 Marks as read in Full View only
#                </option>
#                <option value="always">
#                 Marks as read in Full View and List View
#                </option>
#               </select>
#              </div>
#             </div>
#             <div class="form-group">
#              <label class="col-md-4 control-label" for="user_font_size">
#               Font size for text in posts
#              </label>
#              <input class="hidden" id="user_font_size" name="user[font_size]" type="number" value="13"/>
#              <div class="col-md-8">
#               <div class="row" style="padding-left:15px;">
#                <div class="font-size-selector selected" data-font-size="13" style="font-size:13px;">
#                 <div class="" style="height:100%;width:100%;display:flex;align-items:center;justify-content:center;">
#                  <div class="text">
#                   aA
#                  </div>
#                 </div>
#                </div>
#                <div class="font-size-selector" data-font-size="15" style="font-size:15px;">
#                 <div class="" style="height:100%;width:100%;display:flex;align-items:center;justify-content:center;">
#                  <div class="text">
#                   aA
#                  </div>
#                 </div>
#                </div>
#                <div class="font-size-selector" data-font-size="18" style="font-size:18px;">
#                 <div class="" style="height:100%;width:100%;display:flex;align-items:center;justify-content:center;">
#                  <div class="text">
#                   aA
#                  </div>
#                 </div>
#                </div>
#                <div class="font-size-selector" data-font-size="21" style="font-size:21px;">
#                 <div class="" style="height:100%;width:100%;display:flex;align-items:center;justify-content:center;">
#                  <div class="text">
#                   aA
#                  </div>
#                 </div>
#                </div>
#                <div class="font-size-selector" data-font-size="24" style="font-size:24px;">
#                 <div class="" style="height:100%;width:100%;display:flex;align-items:center;justify-content:center;">
#                  <div class="text">
#                   aA
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="form-group">
#              <div class="col-md-8 col-md-offset-4">
#               <div class="checkbox">
#                <label>
#                 <input name="user[use_spritz]" type="hidden" value="0"/>
#                 <input id="user_use_spritz" name="user[use_spritz]" type="checkbox" value="1"/>
#                 Enable
#                 <a href="http://www.spritzinc.com" rel="noopener noreferrer" target="_blank">
#                  Spritz
#                 </a>
#                 for speedy reading (requires Spritz account)
#                </label>
#               </div>
#               <div class="checkbox">
#                <label>
#                 <input name="user[click_to_scroll]" type="hidden" value="0"/>
#                 <input id="user_click_to_scroll" name="user[click_to_scroll]" type="checkbox" value="1"/>
#                 Clicking on a post scrolls to it
#                </label>
#               </div>
#               <div class="checkbox">
#                <label>
#                 <input name="user[sidebar_unread_only]" type="hidden" value="0"/>
#                 <input id="user_sidebar_unread_only" name="user[sidebar_unread_only]" type="checkbox" value="1"/>
#                 Show only those folders/feeds that have unread items
#                </label>
#               </div>
#               <div class="checkbox">
#                <label>
#                 <input name="user[sidebar_alpha]" type="hidden" value="0"/>
#                 <input id="user_sidebar_alpha" name="user[sidebar_alpha]" type="checkbox" value="1"/>
#                 Sort folders/feeds alphabetically
#                </label>
#               </div>
#               <div class="checkbox">
#                <label>
#                 <input name="user[confirm_read_all]" type="hidden" value="0"/>
#                 <input id="user_confirm_read_all" name="user[confirm_read_all]" type="checkbox" value="1"/>
#                 Protect me from accidentally marking all as read
#                </label>
#               </div>
#               <div class="checkbox">
#                <label>
#                 <input name="user[dark_theme]" type="hidden" value="0"/>
#                 <input id="user_dark_theme" name="user[dark_theme]" type="checkbox" value="1"/>
#                 Enable Dark Mode (can also hit 'd' key to use shortcut)
#                </label>
#               </div>
#              </div>
#             </div>
#             <div class="form-group">
#              <div class="col-md-8 col-md-offset-4">
#               <input class="btn btn-default" name="commit" type="submit" value="Save changes"/>
#              </div>
#             </div>
#            </div>
#           </div>
#          </fieldset>
#         </form>
#         <div class="row">
#          <div class="col-md-12">
#           Unhappy? You can
#           <a href="/feeds.opml" rel="noopener noreferrer" target="_blank">
#            export your feeds
#           </a>
#           as OPML file and
#           <a data-confirm="Are you sure?" data-method="delete" href="/users" rel="nofollow">
#            cancel your account
#           </a>
#           at any time.
#          </div>
#         </div>
#        </div>
#        <iframe src="https://www.subtome.com/register-no-ui.html?name=The+Old+Reader&amp;url=https%3A%2F%2Ftheoldreader.com%2Ffeeds%2Fsubscribe%3Furl%3D%257Bfeed%257D" style="display:none;">
#        </iframe>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" aria-labelledby="new-folder-modal-label" class="modal fade" id="new-folder-modal" role="dialog" tabindex="-1">
#    <div class="modal-dialog" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <h3 id="new-folder-modal-label">
#        Create New Folder
#       </h3>
#      </div>
#      <div class="modal-body">
#       <div class="alert alert-error hidden">
#        Folder name cannot be blank
#       </div>
#       <label>
#        Folder name
#       </label>
#       <input class="rename-textbox form-control" id="create-folder-name" placeholder="Folder name" type="text"/>
#       <input id="new-folder-subscription-id" type="hidden">
#        <input id="new-folder-url" type="hidden"/>
#       </input>
#      </div>
#      <div class="modal-footer">
#       <button aria-hidden="true" class="btn btn-default" data-dismiss="modal">
#        Cancel
#       </button>
#       <a class="btn btn-primary" href="#" id="create-folder-button">
#        Create folder
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" aria-labelledby="shortcuts-label" class="shortcuts modal fade" id="shortcuts" role="dialog" tabindex="-1">
#    <div class="modal-dialog" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <h3 id="shortcuts-label">
#        Keyboard Shortcuts
#       </h3>
#      </div>
#      <div class="modal-body">
#       <div class="row">
#        <div class="col-md-4">
#         <p>
#          Navigate between pages
#         </p>
#         <table>
#          <tr>
#           <td>
#            shift-n, shift-j
#           </td>
#           <td>
#            next subscription or folder
#           </td>
#          </tr>
#          <tr>
#           <td>
#            shift-p, shift-k
#           </td>
#           <td>
#            previous subscription or folder
#           </td>
#          </tr>
#          <tr>
#           <td>
#            shift-x
#           </td>
#           <td>
#            collapse selected folder
#           </td>
#          </tr>
#          <tr>
#           <td>
#            shift-o
#           </td>
#           <td>
#            open selected subscription or folder
#           </td>
#          </tr>
#          <tr>
#           <td>
#            shift-c
#           </td>
#           <td>
#            collapse all folders
#           </td>
#          </tr>
#          <tr>
#           <td>
#            shift-e
#           </td>
#           <td>
#            expand all folders
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then h
#           </td>
#           <td>
#            go to home
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then a
#           </td>
#           <td>
#            go to all items
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then f
#           </td>
#           <td>
#            go to starred
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then l
#           </td>
#           <td>
#            go to liked
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then s
#           </td>
#           <td>
#            go to shared
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then b
#           </td>
#           <td>
#            go to bookmarked
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then t
#           </td>
#           <td>
#            go to trending
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then c
#           </td>
#           <td>
#            go to commented
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then p
#           </td>
#           <td>
#            go to following
#           </td>
#          </tr>
#         </table>
#         <p>
#          Other shortcuts
#         </p>
#         <table>
#          <tr>
#           <td>
#            r
#           </td>
#           <td>
#            refresh current page
#           </td>
#          </tr>
#          <tr>
#           <td>
#            /
#           </td>
#           <td>
#            focus the search field
#           </td>
#          </tr>
#          <tr>
#           <td>
#            a
#           </td>
#           <td>
#            add subscription
#           </td>
#          </tr>
#          <tr>
#           <td>
#            ? or h
#           </td>
#           <td>
#            show this window
#           </td>
#          </tr>
#          <tr>
#           <td>
#            d
#           </td>
#           <td>
#            dark mode
#           </td>
#          </tr>
#         </table>
#        </div>
#        <div class="col-md-4">
#         <p>
#          Shortcuts for posts
#         </p>
#         <table>
#          <tr>
#           <td>
#            space
#           </td>
#           <td>
#            scroll down
#           </td>
#          </tr>
#          <tr>
#           <td>
#            shift+space
#           </td>
#           <td>
#            scroll up
#           </td>
#          </tr>
#          <tr>
#           <td>
#            shift+a
#           </td>
#           <td>
#            mark all as read
#           </td>
#          </tr>
#          <tr>
#           <td>
#            j, n
#           </td>
#           <td>
#            next post
#           </td>
#          </tr>
#          <tr>
#           <td>
#            k, p
#           </td>
#           <td>
#            previous post
#           </td>
#          </tr>
#          <tr>
#           <td>
#            o, v
#           </td>
#           <td>
#            open post in a new tab
#           </td>
#          </tr>
#          <tr>
#           <td>
#            b
#           </td>
#           <td>
#            open post in a background tab*
#           </td>
#          </tr>
#          <tr>
#           <td>
#            x
#           </td>
#           <td>
#            toggle post (list view)
#           </td>
#          </tr>
#          <tr>
#           <td>
#            f
#           </td>
#           <td>
#            star a post
#           </td>
#          </tr>
#          <tr>
#           <td>
#            s
#           </td>
#           <td>
#            share a post
#           </td>
#          </tr>
#          <tr>
#           <td>
#            m
#           </td>
#           <td>
#            read/unread a post
#           </td>
#          </tr>
#          <tr>
#           <td>
#            l
#           </td>
#           <td>
#            mark post as liked
#           </td>
#          </tr>
#          <tr>
#           <td>
#            c
#           </td>
#           <td>
#            scroll to comments and open the form
#           </td>
#          </tr>
#          <tr>
#           <td>
#            i
#           </td>
#           <td>
#            use Spritz to read post
#           </td>
#          </tr>
#          <tr>
#           <td>
#            1
#           </td>
#           <td>
#            switch to full view
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2
#           </td>
#           <td>
#            switch to list view
#           </td>
#          </tr>
#         </table>
#         <small>
#          *Chrome, Safari, Opera only
#         </small>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    window.CONFIG = {
#     environment: "production",
#     assets_host: "//s.theoldreader.com",
#     I18n: {
#       defaultLocale: "en",
#       locale: "en",
#       fallbacks: true
#     }
#   }
#   </script>
#   <script src="//s.theoldreader.com/assets/application-401befeb476c4dda9b851e9a2447795e.js" type="text/javascript">
#   </script>
#   <script src="/ad.min.js">
#   </script>
#   <!-- <script type="text/javascript">
#   if(window.$) {
#     $(function() {
#       if(typeof canRunAdsOnTor === 'undefined') {
#         $('div.sidenav-cell .banner').remove();
#         $('#sidebar').removeClass('banner_user');
#       }
#     });
#   }
# </script> -->
#   <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8488747604526930">
#   </script>
#   <script async="" defer="" src="//platform.instagram.com/en_US/embeds.js">
#   </script>
#   <script>
#    window.twttr = (function (d, s, id) {
#     var t, js, fjs = d.getElementsByTagName(s)[0];
#     if (d.getElementById(id)) return;
#     js = d.createElement(s); js.id = id;
#     js.src= "//platform.twitter.com/widgets.js";
#     fjs.parentNode.insertBefore(js, fjs);
#     return window.twttr || (t = { _e: [], ready: function (f) { t._e.push(f) } });
#   }(document, "script", "twitter-wjs"));
#   </script>
#   <div id="fb-root">
#   </div>
#   <script>
#    (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.5&appId=167033558637456";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#   </script>
#  </body>
# </html>

# %%
# verify successful login: find email and print
import re

email = str(soup4.select('div.col-md-8 > #user_email'))
pattern4 = r'\w+@[a-zA-Z_]+?\.[a-zA-Z]{2,6}' # find email
email_print = re.findall(pattern4, email)[0]

print(email_print)
# Out:
# leoliao@ucdavis.edu
